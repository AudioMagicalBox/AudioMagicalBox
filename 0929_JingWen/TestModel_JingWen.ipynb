# %%
"""將tensorflow檔轉成tensorflow lite，使機器負載量變小"""
from tensorflow import lite
from tensorflow.keras import models

# Parameters
keras_model_filename = './h5/appendEnergyTT_wen.h5' #訓練好的模型
tflite_filename = './tflite/appendEnergyTT_wen.tflite' #預建置檔案

# Convert model to TF Lite model
model = models.load_model(keras_model_filename) #載入本來的模型
converter = lite.TFLiteConverter.from_keras_model(model) #將模型載入轉換器
tflite_model = converter.convert() #進行轉換
open(tflite_filename, 'wb').write(tflite_model) #輸出轉換後的模型
# Out:
# INFO:tensorflow:Assets written to: C:\Users\user\AppData\Local\Temp\tmphg6asl9d\assets
# 239460

# %%
import sounddevice as sd
import numpy as np
import scipy.signal
import python_speech_features
import tensorflow as tf
from PyQt5.QtCore import QTime
import librosa
import random

# This gets called every 0.5 seconds
def sound(window,s,m):
    
    S = np.abs(librosa.stft(window)) #將整個window音訊做stft，並轉成絕對值
    #print(np.sum(S))
    
    if np.sum(S) >= 0: #判斷S的總和是否>3000，如果>3000，代表有講話
        # Compute features
        mfccs = python_speech_features.base.mfcc(window, #輸入訊號
                                            samplerate=8000, #取樣率
                                            winlen=0.256, #音框涵蓋時間
                                            winstep=0.050, #音框間距離
                                            numcep=num_mfcc, #返回係數的量
                                            nfilt=26, #過濾器數量
                                            nfft=2048,#FFT大小
                                            preemph=0.0,#不用預強化濾波器
                                            ceplifter=0,#ROBUST
                                            appendEnergy=True,#True的話，第0個倒頻譜係數被替代成總音框能量的對數
                                            winfunc=np.hanning)#hanning window
        mfccs = mfccs.transpose()
        
        # Make prediction from model
        in_tensor = np.float32(mfccs.reshape(1, mfccs.shape[0], mfccs.shape[1], 1))
        interpreter.set_tensor(input_details[0]['index'], in_tensor)
        interpreter.invoke()
        output_data = interpreter.get_tensor(output_details[0]['index'])
        val = output_data[0][0]
        
        if val > 0.4:
            data.append(str(m) + "分" + str(s) + "秒，出現:" + str("贅詞") + "，" + str(val))
            #data_yes.append(str(m) + "分" + str(s) + "秒，出現:" + str("贅詞") + "，" + str(val) + ",")
        else:
            data.append(str(m) + "分" + str(s) + "秒，出現:" + str("贅詞") + "，" + str(val))
#main
# Parameters
num_mfcc = 23 #回傳mfcc的量
model_path = './tflite/appendEnergyTT_wen.tflite'
#words = ['backgroundNoise', 'ㄏㄧㄡ', 'ㄟ', '吼', '啦', '嗯', '的一個', '的這個', '的那個', '著', '那', '那那個', '阿']#答案對應到的字詞

data = []
data_yes = []
start = 0 #一開始的索引值
end = 2000 #一開始的索引值
s = 0 #秒
m = 0 #分
duration = 180 #讀音檔的總時間
sample_rate = 8000 #取樣率

#載入音檔
y, sr = librosa.load("./desktop/chen.wav",sr=sample_rate,duration=duration) 

# Sliding window
window = np.zeros(8000)#取樣音頻數據變數

# Load model (interpreter)
interpreter = tf.lite.Interpreter(model_path)
interpreter.allocate_tensors()
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

while True:
    s = s + 0.25
    if(s >= 60): #60秒 轉成 1分
        s = 0
        m = m + 1

    window[0:2000] = window[2000:4000]
    window[2000:4000] = window[4000:6000]
    window[4000:6000] = window[6000:8000]
    window[6000:8000] = y[start:end]
    
    sound(window,s,m) #呼叫sound()

    if(end == (8000 * duration)): #如果移動到最後，break
        break
    
    start = start + 2000 #向後移動
    end = end + 2000 #向後移動   
    
    
for i in range(len(data)):
        print(data[i])
    
print(len(data))
# Out:
# 0分0.25秒，出現:贅詞，0.94904244
# 0分0.5秒，出現:贅詞，0.0033058482
# 0分0.75秒，出現:贅詞，0.00076176506
# 0分1.0秒，出現:贅詞，7.772989e-05
# 0分1.25秒，出現:贅詞，1.5796659e-05
# 0分1.5秒，出現:贅詞，3.4986995e-05
# 0分1.75秒，出現:贅詞，2.0653038e-06
# 0分2.0秒，出現:贅詞，1.4763333e-09
# 0分2.25秒，出現:贅詞，3.383291e-12
# 0分2.5秒，出現:贅詞，3.1504471e-12
# 0分2.75秒，出現:贅詞，2.0444956e-13
# 0分3.0秒，出現:贅詞，6.288844e-13
# 0分3.25秒，出現:贅詞，2.2219565e-10
# 0分3.5秒，出現:贅詞，2.6428607e-10
# 0分3.75秒，出現:贅詞，4.2439274e-10
# 0分4.0秒，出現:贅詞，2.1074407e-09
# 0分4.25秒，出現:贅詞，5.0160006e-06
# 0分4.5秒，出現:贅詞，1.3002827e-07
# 0分4.75秒，出現:贅詞，2.4388925e-07
# 0分5.0秒，出現:贅詞，7.170511e-08
# 0分5.25秒，出現:贅詞，3.435016e-07
# 0分5.5秒，出現:贅詞，7.891805e-09
# 0分5.75秒，出現:贅詞，1.7052852e-07
# 0分6.0秒，出現:贅詞，8.688225e-07
# 0分6.25秒，出現:贅詞，6.0004744e-08
# 0分6.5秒，出現:贅詞，1.8011409e-10
# 0分6.75秒，出現:贅詞，6.594373e-11
# 0分7.0秒，出現:贅詞，1.7258568e-08
# 0分7.25秒，出現:贅詞，7.3205924e-06
# 0分7.5秒，出現:贅詞，2.6169488e-05
# 0分7.75秒，出現:贅詞，2.128834e-13
# 0分8.0秒，出現:贅詞，7.2636944e-14
# 0分8.25秒，出現:贅詞，1.0135273e-12
# 0分8.5秒，出現:贅詞，2.796517e-13
# 0分8.75秒，出現:贅詞，9.446135e-12
# 0分9.0秒，出現:贅詞，3.0749941e-10
# 0分9.25秒，出現:贅詞，2.3661776e-11
# 0分9.5秒，出現:贅詞，1.703249e-10
# 0分9.75秒，出現:贅詞，9.535501e-12
# 0分10.0秒，出現:贅詞，2.027416e-14
# 0分10.25秒，出現:贅詞，4.0490215e-12
# 0分10.5秒，出現:贅詞，8.886167e-13
# 0分10.75秒，出現:贅詞，1.20708955e-11
# 0分11.0秒，出現:贅詞，5.494676e-10
# 0分11.25秒，出現:贅詞，5.5996218e-11
# 0分11.5秒，出現:贅詞，1.8041452e-09
# 0分11.75秒，出現:贅詞，3.7880584e-12
# 0分12.0秒，出現:贅詞，2.009807e-09
# 0分12.25秒，出現:贅詞，1.438399e-08
# 0分12.5秒，出現:贅詞，1.3911979e-11
# 0分12.75秒，出現:贅詞，2.5635348e-15
# 0分13.0秒，出現:贅詞，5.984284e-14
# 0分13.25秒，出現:贅詞，6.406256e-10
# 0分13.5秒，出現:贅詞，1.3595569e-08
# 0分13.75秒，出現:贅詞，1.6596219e-12
# 0分14.0秒，出現:贅詞，1.9780211e-10
# 0分14.25秒，出現:贅詞，1.1952038e-06
# 0分14.5秒，出現:贅詞，3.2033865e-06
# 0分14.75秒，出現:贅詞，5.2441683e-05
# 0分15.0秒，出現:贅詞，2.6230694e-08
# 0分15.25秒，出現:贅詞，8.8028584e-10
# 0分15.5秒，出現:贅詞，1.7503009e-10
# 0分15.75秒，出現:贅詞，1.6349012e-11
# 0分16.0秒，出現:贅詞，1.0235679e-11
# 0分16.25秒，出現:贅詞，2.2829023e-09
# 0分16.5秒，出現:贅詞，3.5862407e-10
# 0分16.75秒，出現:贅詞，5.7423916e-11
# 0分17.0秒，出現:贅詞，8.096351e-13
# 0分17.25秒，出現:贅詞，6.259453e-11
# 0分17.5秒，出現:贅詞，3.4676398e-10
# 0分17.75秒，出現:贅詞，1.2519728e-05
# 0分18.0秒，出現:贅詞，9.673534e-08
# 0分18.25秒，出現:贅詞，2.4478005e-08
# 0分18.5秒，出現:贅詞，3.0891188e-12
# 0分18.75秒，出現:贅詞，2.3608863e-11
# 0分19.0秒，出現:贅詞，3.5147894e-13
# 0分19.25秒，出現:贅詞，1.617827e-12
# 0分19.5秒，出現:贅詞，4.702925e-11
# 0分19.75秒，出現:贅詞，1.1726641e-13
# 0分20.0秒，出現:贅詞，1.6560252e-10
# 0分20.25秒，出現:贅詞，2.2772086e-11
# 0分20.5秒，出現:贅詞，4.3133297e-10
# 0分20.75秒，出現:贅詞，6.453429e-10
# 0分21.0秒，出現:贅詞，2.0247456e-11
# 0分21.25秒，出現:贅詞，9.671918e-11
# 0分21.5秒，出現:贅詞，1.2401135e-09
# 0分21.75秒，出現:贅詞，2.6431694e-13
# 0分22.0秒，出現:贅詞，4.0763017e-13
# 0分22.25秒，出現:贅詞，2.3645712e-12
# 0分22.5秒，出現:贅詞，1.1845475e-12
# 0分22.75秒，出現:贅詞，4.980869e-11
# 0分23.0秒，出現:贅詞，3.6665223e-11
# 0分23.25秒，出現:贅詞，3.054465e-08
# 0分23.5秒，出現:贅詞，2.3805134e-08
# 0分23.75秒，出現:贅詞，8.0024115e-10
# 0分24.0秒，出現:贅詞，2.460313e-08
# 0分24.25秒，出現:贅詞，2.7909782e-11
# 0分24.5秒，出現:贅詞，8.700804e-12
# 0分24.75秒，出現:贅詞，3.4127097e-11
# 0分25.0秒，出現:贅詞，3.5805861e-12
# 0分25.25秒，出現:贅詞，5.1066248e-12
# 0分25.5秒，出現:贅詞，2.114046e-11
# 0分25.75秒，出現:贅詞，3.603198e-10
# 0分26.0秒，出現:贅詞，4.468885e-09
# 0分26.25秒，出現:贅詞，6.134482e-11
# 0分26.5秒，出現:贅詞，1.0182638e-09
# 0分26.75秒，出現:贅詞，2.1076064e-12
# 0分27.0秒，出現:贅詞，5.003253e-14
# 0分27.25秒，出現:贅詞，8.192976e-11
# 0分27.5秒，出現:贅詞，6.965946e-07
# 0分27.75秒，出現:贅詞，3.770387e-06
# 0分28.0秒，出現:贅詞，3.163362e-08
# 0分28.25秒，出現:贅詞，3.8631534e-08
# 0分28.5秒，出現:贅詞，1.9455895e-08
# 0分28.75秒，出現:贅詞，8.5251304e-07
# 0分29.0秒，出現:贅詞，4.6227345e-13
# 0分29.25秒，出現:贅詞，1.3748807e-12
# 0分29.5秒，出現:贅詞，3.4797453e-11
# 0分29.75秒，出現:贅詞，5.5458266e-11
# 0分30.0秒，出現:贅詞，8.476175e-13
# 0分30.25秒，出現:贅詞，1.4801612e-12
# 0分30.5秒，出現:贅詞，4.3858376e-12
# 0分30.75秒，出現:贅詞，9.096273e-12
# 0分31.0秒，出現:贅詞，1.1734226e-12
# 0分31.25秒，出現:贅詞，6.0477222e-12
# 0分31.5秒，出現:贅詞，7.530994e-12
# 0分31.75秒，出現:贅詞，3.322377e-10
# 0分32.0秒，出現:贅詞，6.4702675e-08
# 0分32.25秒，出現:贅詞，4.9757265e-08
# 0分32.5秒，出現:贅詞，2.7576427e-10
# 0分32.75秒，出現:贅詞，4.6981984e-11
# 0分33.0秒，出現:贅詞，8.0509584e-13
# 0分33.25秒，出現:贅詞，6.937772e-11
# 0分33.5秒，出現:贅詞，1.2039002e-09
# 0分33.75秒，出現:贅詞，4.8494945e-07
# 0分34.0秒，出現:贅詞，2.9320134e-08
# 0分34.25秒，出現:贅詞，6.7421774e-10
# 0分34.5秒，出現:贅詞，5.8503515e-15
# 0分34.75秒，出現:贅詞，3.5322402e-14
# 0分35.0秒，出現:贅詞，3.5422657e-14
# 0分35.25秒，出現:贅詞，1.8076478e-12
# 0分35.5秒，出現:贅詞，5.4524933e-11
# 0分35.75秒，出現:贅詞，6.3589146e-06
# 0分36.0秒，出現:贅詞，0.0005242441
# 0分36.25秒，出現:贅詞，3.7902926e-06
# 0分36.5秒，出現:贅詞，6.8995305e-08
# 0分36.75秒，出現:贅詞，2.2700361e-14
# 0分37.0秒，出現:贅詞，4.956222e-13
# 0分37.25秒，出現:贅詞，9.266552e-11
# 0分37.5秒，出現:贅詞，6.018457e-11
# 0分37.75秒，出現:贅詞，9.335769e-13
# 0分38.0秒，出現:贅詞，5.419828e-12
# 0分38.25秒，出現:贅詞，2.7638905e-10
# 0分38.5秒，出現:贅詞，2.189399e-09
# 0分38.75秒，出現:贅詞，6.006562e-09
# 0分39.0秒，出現:贅詞，2.0225312e-10
# 0分39.25秒，出現:贅詞，1.30555495e-08
# 0分39.5秒，出現:贅詞，2.8546053e-11
# 0分39.75秒，出現:贅詞，2.0544726e-09
# 0分40.0秒，出現:贅詞，1.8620682e-08
# 0分40.25秒，出現:贅詞，1.2824454e-12
# 0分40.5秒，出現:贅詞，1.7778788e-14
# 0分40.75秒，出現:贅詞，1.5497057e-14
# 0分41.0秒，出現:贅詞，3.637581e-13
# 0分41.25秒，出現:贅詞，1.38015e-10
# 0分41.5秒，出現:贅詞，6.890567e-11
# 0分41.75秒，出現:贅詞，1.6077584e-09
# 0分42.0秒，出現:贅詞，6.900698e-10
# 0分42.25秒，出現:贅詞，5.9443373e-08
# 0分42.5秒，出現:贅詞，1.2133762e-06
# 0分42.75秒，出現:贅詞，1.0887615e-10
# 0分43.0秒，出現:贅詞，6.7053215e-13
# 0分43.25秒，出現:贅詞，7.032975e-13
# 0分43.5秒，出現:贅詞，2.9452745e-13
# 0分43.75秒，出現:贅詞，9.681336e-12
# 0分44.0秒，出現:贅詞，9.242374e-13
# 0分44.25秒，出現:贅詞，1.2604349e-09
# 0分44.5秒，出現:贅詞，5.053855e-10
# 0分44.75秒，出現:贅詞，2.5774354e-12
# 0分45.0秒，出現:贅詞，3.665739e-11
# 0分45.25秒，出現:贅詞，2.2058238e-12
# 0分45.5秒，出現:贅詞，1.6221397e-11
# 0分45.75秒，出現:贅詞，2.4987732e-09
# 0分46.0秒，出現:贅詞，2.3369486e-07
# 0分46.25秒，出現:贅詞，2.5333934e-06
# 0分46.5秒，出現:贅詞，1.5379076e-06
# 0分46.75秒，出現:贅詞，1.62838e-05
# 0分47.0秒，出現:贅詞，0.00041407847
# 0分47.25秒，出現:贅詞，0.00052569323
# 0分47.5秒，出現:贅詞，0.00033994555
# 0分47.75秒，出現:贅詞，0.00050546456
# 0分48.0秒，出現:贅詞，0.00040276503
# 0分48.25秒，出現:贅詞，2.1009888e-05
# 0分48.5秒，出現:贅詞，2.84048e-08
# 0分48.75秒，出現:贅詞，3.8757086e-10
# 0分49.0秒，出現:贅詞，3.5589944e-09
# 0分49.25秒，出現:贅詞，5.84347e-07
# 0分49.5秒，出現:贅詞，4.562476e-05
# 0分49.75秒，出現:贅詞，0.0003133245
# 0分50.0秒，出現:贅詞，0.00030067153
# 0分50.25秒，出現:贅詞，0.00041195197
# 0分50.5秒，出現:贅詞，0.0006249436
# 0分50.75秒，出現:贅詞，0.0009845841
# 0分51.0秒，出現:贅詞，2.523727e-07
# 0分51.25秒，出現:贅詞，3.895694e-08
# 0分51.5秒，出現:贅詞，3.5919462e-11
# 0分51.75秒，出現:贅詞，8.001378e-13
# 0分52.0秒，出現:贅詞，1.4491045e-09
# 0分52.25秒，出現:贅詞，5.2509307e-07
# 0分52.5秒，出現:贅詞，1.304292e-10
# 0分52.75秒，出現:贅詞，1.001355e-12
# 0分53.0秒，出現:贅詞，1.0705899e-15
# 0分53.25秒，出現:贅詞，2.2582927e-12
# 0分53.5秒，出現:贅詞，1.3144388e-07
# 0分53.75秒，出現:贅詞，3.5181645e-07
# 0分54.0秒，出現:贅詞，5.4814393e-07
# 0分54.25秒，出現:贅詞，1.1180543e-06
# 0分54.5秒，出現:贅詞，7.1714514e-12
# 0分54.75秒，出現:贅詞，1.0117501e-10
# 0分55.0秒，出現:贅詞，1.7020364e-10
# 0分55.25秒，出現:贅詞，5.0221657e-11
# 0分55.5秒，出現:贅詞，3.0305172e-09
# 0分55.75秒，出現:贅詞，9.397076e-09
# 0分56.0秒，出現:贅詞，1.0832474e-08
# 0分56.25秒，出現:贅詞，2.0611723e-09
# 0分56.5秒，出現:贅詞，6.9409884e-07
# 0分56.75秒，出現:贅詞，1.7479715e-08
# 0分57.0秒，出現:贅詞，7.3706815e-14
# 0分57.25秒，出現:贅詞，5.7481218e-11
# 0分57.5秒，出現:贅詞，2.429918e-13
# 0分57.75秒，出現:贅詞，3.0917738e-13
# 0分58.0秒，出現:贅詞，8.8699556e-13
# 0分58.25秒，出現:贅詞，3.3612976e-15
# 0分58.5秒，出現:贅詞，8.777322e-14
# 0分58.75秒，出現:贅詞，8.04408e-15
# 0分59.0秒，出現:贅詞，7.035499e-15
# 0分59.25秒，出現:贅詞，1.8076264e-09
# 0分59.5秒，出現:贅詞，1.7662825e-09
# 0分59.75秒，出現:贅詞，1.9352895e-09
# 1分0秒，出現:贅詞，7.444555e-15
# 1分0.25秒，出現:贅詞，4.0931022e-11
# 1分0.5秒，出現:贅詞，3.691995e-12
# 1分0.75秒，出現:贅詞，1.1582278e-12
# 1分1.0秒，出現:贅詞，8.254917e-12
# 1分1.25秒，出現:贅詞，2.9820482e-10
# 1分1.5秒，出現:贅詞，1.0547049e-08
# 1分1.75秒，出現:贅詞，1.1642971e-10
# 1分2.0秒，出現:贅詞，1.38752135e-11
# 1分2.25秒，出現:贅詞，1.9286985e-09
# 1分2.5秒，出現:贅詞，1.3677387e-11
# 1分2.75秒，出現:贅詞，3.3267176e-09
# 1分3.0秒，出現:贅詞，3.6285093e-09
# 1分3.25秒，出現:贅詞，1.4871904e-08
# 1分3.5秒，出現:贅詞，1.8400347e-09
# 1分3.75秒，出現:贅詞，8.204257e-11
# 1分4.0秒，出現:贅詞，5.237938e-10
# 1分4.25秒，出現:贅詞，3.181536e-06
# 1分4.5秒，出現:贅詞，5.0764116e-05
# 1分4.75秒，出現:贅詞，0.00017386777
# 1分5.0秒，出現:贅詞，0.0012598541
# 1分5.25秒，出現:贅詞，0.0019082824
# 1分5.5秒，出現:贅詞，0.00015958017
# 1分5.75秒，出現:贅詞，0.00010807404
# 1分6.0秒，出現:贅詞，0.0005174833
# 1分6.25秒，出現:贅詞，0.00011573768
# 1分6.5秒，出現:贅詞，0.00035566144
# 1分6.75秒，出現:贅詞，7.873612e-05
# 1分7.0秒，出現:贅詞，1.425391e-05
# 1分7.25秒，出現:贅詞，1.9713564e-06
# 1分7.5秒，出現:贅詞，6.1565237e-07
# 1分7.75秒，出現:贅詞，4.9579366e-14
# 1分8.0秒，出現:贅詞，4.059644e-14
# 1分8.25秒，出現:贅詞，4.3057073e-12
# 1分8.5秒，出現:贅詞，1.3895562e-12
# 1分8.75秒，出現:贅詞，2.980409e-11
# 1分9.0秒，出現:贅詞，5.881288e-07
# 1分9.25秒，出現:贅詞，9.536309e-05
# 1分9.5秒，出現:贅詞，6.333664e-05
# 1分9.75秒，出現:贅詞，3.0075853e-06
# 1分10.0秒，出現:贅詞，6.3866355e-05
# 1分10.25秒，出現:贅詞，1.2065879e-05
# 1分10.5秒，出現:贅詞，6.703197e-11
# 1分10.75秒，出現:贅詞，1.3034433e-11
# 1分11.0秒，出現:贅詞，4.577633e-12
# 1分11.25秒，出現:贅詞，1.1982562e-10
# 1分11.5秒，出現:贅詞，8.34777e-09
# 1分11.75秒，出現:贅詞，1.6007872e-08
# 1分12.0秒，出現:贅詞，7.360128e-08
# 1分12.25秒，出現:贅詞，1.9221607e-05
# 1分12.5秒，出現:贅詞，6.0587713e-06
# 1分12.75秒，出現:贅詞，8.288925e-08
# 1分13.0秒，出現:贅詞，0.00027489828
# 1分13.25秒，出現:贅詞，1.5571773e-05
# 1分13.5秒，出現:贅詞，4.905151e-08
# 1分13.75秒，出現:贅詞，7.9394236e-10
# 1分14.0秒，出現:贅詞，1.2858643e-13
# 1分14.25秒，出現:贅詞，1.2428715e-12
# 1分14.5秒，出現:贅詞，3.3319418e-09
# 1分14.75秒，出現:贅詞，1.5023026e-07
# 1分15.0秒，出現:贅詞，8.753172e-08
# 1分15.25秒，出現:贅詞，2.0663365e-11
# 1分15.5秒，出現:贅詞，2.6828417e-10
# 1分15.75秒，出現:贅詞，2.9592113e-09
# 1分16.0秒，出現:贅詞，1.0416759e-06
# 1分16.25秒，出現:贅詞，3.6186862e-07
# 1分16.5秒，出現:贅詞，8.7395396e-11
# 1分16.75秒，出現:贅詞，1.5360668e-14
# 1分17.0秒，出現:贅詞，5.630154e-16
# 1分17.25秒，出現:贅詞，5.6371216e-15
# 1分17.5秒，出現:贅詞，6.4069323e-13
# 1分17.75秒，出現:贅詞，9.892107e-12
# 1分18.0秒，出現:贅詞，2.9528639e-12
# 1分18.25秒，出現:贅詞，7.4928334e-11
# 1分18.5秒，出現:贅詞，1.0660501e-07
# 1分18.75秒，出現:贅詞，4.9196046e-07
# 1分19.0秒，出現:贅詞，9.629965e-10
# 1分19.25秒，出現:贅詞，3.4478998e-07
# 1分19.5秒，出現:贅詞，1.023091e-06
# 1分19.75秒，出現:贅詞，4.1864564e-07
# 1分20.0秒，出現:贅詞，9.545341e-09
# 1分20.25秒，出現:贅詞，6.696346e-10
# 1分20.5秒，出現:贅詞，1.8773385e-09
# 1分20.75秒，出現:贅詞，1.1211579e-06
# 1分21.0秒，出現:贅詞，2.1444935e-06
# 1分21.25秒，出現:贅詞，2.4607304e-12
# 1分21.5秒，出現:贅詞，6.3632227e-13
# 1分21.75秒，出現:贅詞，1.7939899e-12
# 1分22.0秒，出現:贅詞，6.867426e-11
# 1分22.25秒，出現:贅詞，1.3397752e-10
# 1分22.5秒，出現:贅詞，3.475969e-07
# 1分22.75秒，出現:贅詞，1.6591447e-06
# 1分23.0秒，出現:贅詞，4.8633922e-08
# 1分23.25秒，出現:贅詞，2.7420243e-05
# 1分23.5秒，出現:贅詞，2.0791107e-05
# 1分23.75秒，出現:贅詞，1.7419381e-06
# 1分24.0秒，出現:贅詞，2.2447881e-09
# 1分24.25秒，出現:贅詞，2.0050845e-09
# 1分24.5秒，出現:贅詞，9.222021e-11
# 1分24.75秒，出現:贅詞，5.572175e-13
# 1分25.0秒，出現:贅詞，4.6900927e-13
# 1分25.25秒，出現:贅詞，4.0511128e-10
# 1分25.5秒，出現:贅詞，1.0024139e-06
# 1分25.75秒，出現:贅詞，6.86487e-07
# 1分26.0秒，出現:贅詞，1.828121e-06
# 1分26.25秒，出現:贅詞，9.201034e-11
# 1分26.5秒，出現:贅詞，8.0916433e-16
# 1分26.75秒，出現:贅詞，6.853604e-14
# 1分27.0秒，出現:贅詞，1.024318e-13
# 1分27.25秒，出現:贅詞，4.6639734e-11
# 1分27.5秒，出現:贅詞，5.299809e-08
# 1分27.75秒，出現:贅詞，7.061356e-12
# 1分28.0秒，出現:贅詞，6.49684e-14
# 1分28.25秒，出現:贅詞，2.6870726e-13
# 1分28.5秒，出現:贅詞，2.3863067e-09
# 1分28.75秒，出現:贅詞，1.664005e-07
# 1分29.0秒，出現:贅詞，7.754529e-09
# 1分29.25秒，出現:贅詞，1.20087785e-11
# 1分29.5秒，出現:贅詞，3.627461e-11
# 1分29.75秒，出現:贅詞，8.4283247e-10
# 1分30.0秒，出現:贅詞，2.2659665e-09
# 1分30.25秒，出現:贅詞，9.105934e-09
# 1分30.5秒，出現:贅詞，2.7026047e-07
# 1分30.75秒，出現:贅詞，4.05607e-08
# 1分31.0秒，出現:贅詞，6.951118e-07
# 1分31.25秒，出現:贅詞，1.9305546e-09
# 1分31.5秒，出現:贅詞，3.1692016e-09
# 1分31.75秒，出現:贅詞，3.327095e-11
# 1分32.0秒，出現:贅詞，7.3659585e-11
# 1分32.25秒，出現:贅詞，4.9251896e-09
# 1分32.5秒，出現:贅詞，1.6115349e-11
# 1分32.75秒，出現:贅詞，5.2003608e-14
# 1分33.0秒，出現:贅詞，6.3375e-13
# 1分33.25秒，出現:贅詞，5.172523e-13
# 1分33.5秒，出現:贅詞，5.4388894e-14
# 1分33.75秒，出現:贅詞，4.4744528e-11
# 1分34.0秒，出現:贅詞，4.0067602e-10
# 1分34.25秒，出現:贅詞，3.6318806e-11
# 1分34.5秒，出現:贅詞，1.4571383e-09
# 1分34.75秒，出現:贅詞，3.3390848e-09
# 1分35.0秒，出現:贅詞，2.1294431e-07
# 1分35.25秒，出現:贅詞，1.0988513e-09
# 1分35.5秒，出現:贅詞，1.0417583e-11
# 1分35.75秒，出現:贅詞，1.3105394e-11
# 1分36.0秒，出現:贅詞，2.7999267e-09
# 1分36.25秒，出現:贅詞，3.8104044e-08
# 1分36.5秒，出現:贅詞，6.7871724e-06
# 1分36.75秒，出現:贅詞，2.7010415e-11
# 1分37.0秒，出現:贅詞，5.623914e-14
# 1分37.25秒，出現:贅詞，9.304547e-14
# 1分37.5秒，出現:贅詞，1.232906e-10
# 1分37.75秒，出現:贅詞，2.8378467e-12
# 1分38.0秒，出現:贅詞，7.6266216e-10
# 1分38.25秒，出現:贅詞，7.6336354e-11
# 1分38.5秒，出現:贅詞，2.4587016e-10
# 1分38.75秒，出現:贅詞，1.5869746e-05
# 1分39.0秒，出現:贅詞，2.4395177e-09
# 1分39.25秒，出現:贅詞，6.84971e-11
# 1分39.5秒，出現:贅詞，2.1037972e-11
# 1分39.75秒，出現:贅詞，4.4851975e-10
# 1分40.0秒，出現:贅詞，3.761305e-09
# 1分40.25秒，出現:贅詞，8.244061e-08
# 1分40.5秒，出現:贅詞，4.2537376e-06
# 1分40.75秒，出現:贅詞，1.5120358e-12
# 1分41.0秒，出現:贅詞，1.7610568e-16
# 1分41.25秒，出現:贅詞，6.193445e-13
# 1分41.5秒，出現:贅詞，1.0006548e-08
# 1分41.75秒，出現:贅詞，9.13918e-14
# 1分42.0秒，出現:贅詞，7.7139135e-14
# 1分42.25秒，出現:贅詞，2.3771726e-13
# 1分42.5秒，出現:贅詞，2.1720809e-12
# 1分42.75秒，出現:贅詞，1.026713e-11
# 1分43.0秒，出現:贅詞，1.3203301e-10
# 1分43.25秒，出現:贅詞，3.0313535e-07
# 1分43.5秒，出現:贅詞，5.1304037e-06
# 1分43.75秒，出現:贅詞，1.828257e-07
# 1分44.0秒，出現:贅詞，2.7582222e-14
# 1分44.25秒，出現:贅詞，2.980653e-16
# 1分44.5秒，出現:贅詞，1.01757775e-13
# 1分44.75秒，出現:贅詞，2.0428742e-13
# 1分45.0秒，出現:贅詞，8.128944e-11
# 1分45.25秒，出現:贅詞，4.969851e-09
# 1分45.5秒，出現:贅詞，1.2122551e-11
# 1分45.75秒，出現:贅詞，5.0256126e-11
# 1分46.0秒，出現:贅詞，9.2179604e-11
# 1分46.25秒，出現:贅詞，1.6949462e-08
# 1分46.5秒，出現:贅詞，5.88567e-09
# 1分46.75秒，出現:贅詞，4.1539774e-16
# 1分47.0秒，出現:贅詞，1.9148273e-13
# 1分47.25秒，出現:贅詞，7.8624e-12
# 1分47.5秒，出現:贅詞，1.2159126e-15
# 1分47.75秒，出現:贅詞，8.793722e-14
# 1分48.0秒，出現:贅詞，1.688074e-13
# 1分48.25秒，出現:贅詞，1.9824465e-12
# 1分48.5秒，出現:贅詞，2.475602e-11
# 1分48.75秒，出現:贅詞，8.274404e-16
# 1分49.0秒，出現:贅詞，2.8817083e-13
# 1分49.25秒，出現:贅詞，3.7379997e-09
# 1分49.5秒，出現:贅詞，1.0517371e-06
# 1分49.75秒，出現:贅詞，7.5671295e-08
# 1分50.0秒，出現:贅詞，1.267894e-09
# 1分50.25秒，出現:贅詞，1.5268705e-11
# 1分50.5秒，出現:贅詞，5.6009847e-10
# 1分50.75秒，出現:贅詞，3.3795042e-09
# 1分51.0秒，出現:贅詞，6.952441e-07
# 1分51.25秒，出現:贅詞，3.2517572e-10
# 1分51.5秒，出現:贅詞，5.1695535e-13
# 1分51.75秒，出現:贅詞，2.256901e-14
# 1分52.0秒，出現:贅詞，2.8156787e-12
# 1分52.25秒，出現:贅詞，1.8152028e-10
# 1分52.5秒，出現:贅詞，1.5669632e-11
# 1分52.75秒，出現:贅詞，2.9362535e-12
# 1分53.0秒，出現:贅詞，3.1483833e-11
# 1分53.25秒，出現:贅詞，7.645255e-10
# 1分53.5秒，出現:贅詞，1.7432301e-10
# 1分53.75秒，出現:贅詞，2.7746105e-09
# 1分54.0秒，出現:贅詞，4.6926622e-11
# 1分54.25秒，出現:贅詞，1.7695613e-09
# 1分54.5秒，出現:贅詞，2.857421e-13
# 1分54.75秒，出現:贅詞，1.2232154e-08
# 1分55.0秒，出現:贅詞，9.0346774e-08
# 1分55.25秒，出現:贅詞，4.1587735e-14
# 1分55.5秒，出現:贅詞，1.0721306e-12
# 1分55.75秒，出現:贅詞，1.1502101e-10
# 1分56.0秒，出現:贅詞，1.1901391e-08
# 1分56.25秒，出現:贅詞，1.2609921e-10
# 1分56.5秒，出現:贅詞，4.850458e-10
# 1分56.75秒，出現:贅詞，3.3464588e-08
# 1分57.0秒，出現:贅詞，4.2051707e-07
# 1分57.25秒，出現:贅詞，1.1716736e-10
# 1分57.5秒，出現:贅詞，1.012108e-11
# 1分57.75秒，出現:贅詞，2.8193296e-12
# 1分58.0秒，出現:贅詞，1.4897953e-12
# 1分58.25秒，出現:贅詞，1.0662748e-11
# 1分58.5秒，出現:贅詞，3.640498e-12
# 1分58.75秒，出現:贅詞，1.2942937e-11
# 1分59.0秒，出現:贅詞，6.109743e-10
# 1分59.25秒，出現:贅詞，2.399372e-11
# 1分59.5秒，出現:贅詞，3.2097867e-09
# 1分59.75秒，出現:贅詞，1.3949156e-10
# 2分0秒，出現:贅詞，1.4209313e-10
# 2分0.25秒，出現:贅詞，1.2464443e-10
# 2分0.5秒，出現:贅詞，4.0505993e-10
# 2分0.75秒，出現:贅詞，9.145645e-11
# 2分1.0秒，出現:贅詞，2.058928e-08
# 2分1.25秒，出現:贅詞，9.003928e-15
# 2分1.5秒，出現:贅詞，3.7266787e-11
# 2分1.75秒，出現:贅詞，1.6195605e-10
# 2分2.0秒，出現:贅詞，1.0886502e-11
# 2分2.25秒，出現:贅詞，1.1081521e-09
# 2分2.5秒，出現:贅詞，1.8756732e-07
# 2分2.75秒，出現:贅詞，2.7044197e-07
# 2分3.0秒，出現:贅詞，5.3236595e-06
# 2分3.25秒，出現:贅詞，4.832048e-07
# 2分3.5秒，出現:贅詞，1.443879e-08
# 2分3.75秒，出現:贅詞，3.8244874e-09
# 2分4.0秒，出現:贅詞，1.5690736e-08
# 2分4.25秒，出現:贅詞，5.424593e-11
# 2分4.5秒，出現:贅詞，1.560198e-11
# 2分4.75秒，出現:贅詞，2.8775884e-09
# 2分5.0秒，出現:贅詞，6.0965593e-09
# 2分5.25秒，出現:贅詞，2.4265313e-07
# 2分5.5秒，出現:贅詞，1.9806528e-08
# 2分5.75秒，出現:贅詞，1.4525661e-10
# 2分6.0秒，出現:贅詞，6.2797816e-11
# 2分6.25秒，出現:贅詞，1.142871e-11
# 2分6.5秒，出現:贅詞，9.465769e-12
# 2分6.75秒，出現:贅詞，7.3829747e-09
# 2分7.0秒，出現:贅詞，3.6417263e-09
# 2分7.25秒，出現:贅詞，1.2166221e-09
# 2分7.5秒，出現:贅詞，1.2202962e-11
# 2分7.75秒，出現:贅詞，9.56997e-14
# 2分8.0秒，出現:贅詞，1.2854234e-12
# 2分8.25秒，出現:贅詞，1.08220775e-08
# 2分8.5秒，出現:贅詞，8.788059e-07
# 2分8.75秒，出現:贅詞，3.725728e-07
# 2分9.0秒，出現:贅詞，0.00021204405
# 2分9.25秒，出現:贅詞，0.00019631293
# 2分9.5秒，出現:贅詞，4.207302e-06
# 2分9.75秒，出現:贅詞，4.6563736e-07
# 2分10.0秒，出現:贅詞，1.5248211e-10
# 2分10.25秒，出現:贅詞，1.0829214e-12
# 2分10.5秒，出現:贅詞，2.1042398e-10
# 2分10.75秒，出現:贅詞，3.5384043e-10
# 2分11.0秒，出現:贅詞，2.0358269e-10
# 2分11.25秒，出現:贅詞，1.6540788e-09
# 2分11.5秒，出現:贅詞，6.964507e-08
# 2分11.75秒，出現:贅詞，4.738793e-08
# 2分12.0秒，出現:贅詞，3.612904e-07
# 2分12.25秒，出現:贅詞，2.301932e-11
# 2分12.5秒，出現:贅詞，1.1866714e-11
# 2分12.75秒，出現:贅詞，3.661235e-12
# 2分13.0秒，出現:贅詞，1.5711908e-13
# 2分13.25秒，出現:贅詞，1.0373076e-10
# 2分13.5秒，出現:贅詞，3.9561672e-07
# 2分13.75秒，出現:贅詞，1.3324137e-06
# 2分14.0秒，出現:贅詞，1.072299e-08
# 2分14.25秒，出現:贅詞，3.7893564e-08
# 2分14.5秒，出現:贅詞，5.7106533e-09
# 2分14.75秒，出現:贅詞，1.1156506e-17
# 2分15.0秒，出現:贅詞，2.556704e-15
# 2分15.25秒，出現:贅詞，5.485347e-11
# 2分15.5秒，出現:贅詞，7.585873e-10
# 2分15.75秒，出現:贅詞，8.699708e-09
# 2分16.0秒，出現:贅詞，4.392379e-10
# 2分16.25秒，出現:贅詞，7.704348e-12
# 2分16.5秒，出現:贅詞，8.273001e-13
# 2分16.75秒，出現:贅詞，3.5187822e-13
# 2分17.0秒，出現:贅詞，1.9425828e-12
# 2分17.25秒，出現:贅詞，4.95023e-10
# 2分17.5秒，出現:贅詞，4.139813e-06
# 2分17.75秒，出現:贅詞，1.7147772e-07
# 2分18.0秒，出現:贅詞，3.9011784e-06
# 2分18.25秒，出現:贅詞，2.8689614e-08
# 2分18.5秒，出現:贅詞，8.467214e-09
# 2分18.75秒，出現:贅詞，1.4370184e-07
# 2分19.0秒，出現:贅詞，9.083648e-10
# 2分19.25秒，出現:贅詞，1.0192258e-10
# 2分19.5秒，出現:贅詞，1.0507538e-09
# 2分19.75秒，出現:贅詞，8.1762515e-08
# 2分20.0秒，出現:贅詞，1.7543229e-08
# 2分20.25秒，出現:贅詞，3.474734e-11
# 2分20.5秒，出現:贅詞，3.4992686e-12
# 2分20.75秒，出現:贅詞，1.8120126e-13
# 2分21.0秒，出現:贅詞，5.1292637e-11
# 2分21.25秒，出現:贅詞，4.9594266e-08
# 2分21.5秒，出現:贅詞，1.0456914e-06
# 2分21.75秒，出現:贅詞，5.1360963e-08
# 2分22.0秒，出現:贅詞，7.2039485e-10
# 2分22.25秒，出現:贅詞，2.1770333e-08
# 2分22.5秒，出現:贅詞，9.58852e-12
# 2分22.75秒，出現:贅詞，5.459459e-09
# 2分23.0秒，出現:贅詞，9.544276e-10
# 2分23.25秒，出現:贅詞，1.7334544e-11
# 2分23.5秒，出現:贅詞，2.6408115e-10
# 2分23.75秒，出現:贅詞，5.4466847e-07
# 2分24.0秒，出現:贅詞，5.9290112e-08
# 2分24.25秒，出現:贅詞，3.8227193e-14
# 2分24.5秒，出現:贅詞，6.319417e-14
# 2分24.75秒，出現:贅詞，2.0440878e-11
# 2分25.0秒，出現:贅詞，1.0765173e-08
# 2分25.25秒，出現:贅詞，4.412001e-07
# 2分25.5秒，出現:贅詞，2.4889e-09
# 2分25.75秒，出現:贅詞，5.5928234e-10
# 2分26.0秒，出現:贅詞，8.5748847e-10
# 2分26.25秒，出現:贅詞，3.2301386e-08
# 2分26.5秒，出現:贅詞，2.7570482e-07
# 2分26.75秒，出現:贅詞，1.75277e-07
# 2分27.0秒，出現:贅詞，1.0786557e-08
# 2分27.25秒，出現:贅詞，3.5109603e-11
# 2分27.5秒，出現:贅詞，4.7573792e-11
# 2分27.75秒，出現:贅詞，2.7761717e-11
# 2分28.0秒，出現:贅詞，1.8648276e-11
# 2分28.25秒，出現:贅詞，5.18113e-12
# 2分28.5秒，出現:贅詞，2.6300333e-11
# 2分28.75秒，出現:贅詞，3.8121527e-11
# 2分29.0秒，出現:贅詞，2.7290909e-08
# 2分29.25秒，出現:贅詞，4.9117105e-05
# 2分29.5秒，出現:贅詞，6.188982e-08
# 2分29.75秒，出現:贅詞，9.551079e-09
# 2分30.0秒，出現:贅詞，4.18561e-08
# 2分30.25秒，出現:贅詞，1.29412e-11
# 2分30.5秒，出現:贅詞，3.7894255e-14
# 2分30.75秒，出現:贅詞，1.4852524e-11
# 2分31.0秒，出現:贅詞，3.9621605e-12
# 2分31.25秒，出現:贅詞，1.0378863e-08
# 2分31.5秒，出現:贅詞，4.0498954e-10
# 2分31.75秒，出現:贅詞，5.1575143e-11
# 2分32.0秒，出現:贅詞，8.951382e-11
# 2分32.25秒，出現:贅詞，9.3354794e-12
# 2分32.5秒，出現:贅詞，1.7677249e-11
# 2分32.75秒，出現:贅詞，1.0587163e-08
# 2分33.0秒，出現:贅詞，3.772305e-10
# 2分33.25秒，出現:贅詞，3.2748817e-06
# 2分33.5秒，出現:贅詞，1.5258687e-11
# 2分33.75秒，出現:贅詞，5.38534e-13
# 2分34.0秒，出現:贅詞，1.0669219e-11
# 2分34.25秒，出現:贅詞，8.438114e-12
# 2分34.5秒，出現:贅詞，2.5116298e-12
# 2分34.75秒，出現:贅詞，2.1427145e-10
# 2分35.0秒，出現:贅詞，9.837243e-12
# 2分35.25秒，出現:贅詞，1.8293896e-08
# 2分35.5秒，出現:贅詞，7.1731495e-07
# 2分35.75秒，出現:贅詞，5.912491e-07
# 2分36.0秒，出現:贅詞，2.7445182e-08
# 2分36.25秒，出現:贅詞，1.6923807e-09
# 2分36.5秒，出現:贅詞，4.812795e-13
# 2分36.75秒，出現:贅詞，1.3385185e-12
# 2分37.0秒，出現:贅詞，5.5880357e-12
# 2分37.25秒，出現:贅詞，4.2338883e-15
# 2分37.5秒，出現:贅詞，1.5482797e-12
# 2分37.75秒，出現:贅詞，7.514215e-10
# 2分38.0秒，出現:贅詞，1.9059321e-07
# 2分38.25秒，出現:贅詞，1.3171045e-08
# 2分38.5秒，出現:贅詞，1.9004704e-09
# 2分38.75秒，出現:贅詞，1.9772232e-13
# 2分39.0秒，出現:贅詞，2.3469668e-12
# 2分39.25秒，出現:贅詞，6.060463e-13
# 2分39.5秒，出現:贅詞，1.6147091e-13
# 2分39.75秒，出現:贅詞，2.5777666e-11
# 2分40.0秒，出現:贅詞，1.815808e-06
# 2分40.25秒，出現:贅詞，3.4084776e-06
# 2分40.5秒，出現:贅詞，5.716241e-10
# 2分40.75秒，出現:贅詞，2.279703e-09
# 2分41.0秒，出現:贅詞，7.0658093e-09
# 2分41.25秒，出現:贅詞，1.9548294e-08
# 2分41.5秒，出現:贅詞，1.0221181e-05
# 2分41.75秒，出現:贅詞，5.262769e-10
# 2分42.0秒，出現:贅詞，9.063821e-08
# 2分42.25秒，出現:贅詞，6.071206e-10
# 2分42.5秒，出現:贅詞，8.051962e-12
# 2分42.75秒，出現:贅詞，1.5449808e-06
# 2分43.0秒，出現:贅詞，7.590582e-06
# 2分43.25秒，出現:贅詞，6.438089e-11
# 2分43.5秒，出現:贅詞，3.7671797e-12
# 2分43.75秒，出現:贅詞，1.9990681e-11
# 2分44.0秒，出現:贅詞，4.667735e-10
# 2分44.25秒，出現:贅詞，1.2446211e-10
# 2分44.5秒，出現:贅詞，3.654549e-09
# 2分44.75秒，出現:贅詞，1.7066643e-13
# 2分45.0秒，出現:贅詞，8.4212314e-13
# 2分45.25秒，出現:贅詞，1.5420218e-12
# 2分45.5秒，出現:贅詞，1.4934155e-10
# 2分45.75秒，出現:贅詞，5.5490758e-11
# 2分46.0秒，出現:贅詞，4.2727915e-09
# 2分46.25秒，出現:贅詞，8.346313e-08
# 2分46.5秒，出現:贅詞，9.214081e-06
# 2分46.75秒，出現:贅詞，1.2416472e-05
# 2分47.0秒，出現:贅詞，3.5895087e-07
# 2分47.25秒，出現:贅詞，2.19488e-08
# 2分47.5秒，出現:贅詞，4.4102732e-11
# 2分47.75秒，出現:贅詞，3.952702e-12
# 2分48.0秒，出現:贅詞，5.283008e-11
# 2分48.25秒，出現:贅詞，6.5555508e-09
# 2分48.5秒，出現:贅詞，7.6000647e-06
# 2分48.75秒，出現:贅詞，1.3503509e-09
# 2分49.0秒，出現:贅詞，1.9487769e-12
# 2分49.25秒，出現:贅詞，2.8413091e-11
# 2分49.5秒，出現:贅詞，3.6492627e-12
# 2分49.75秒，出現:贅詞，9.150572e-10
# 2分50.0秒，出現:贅詞，1.6157232e-09
# 2分50.25秒，出現:贅詞，3.2448624e-09
# 2分50.5秒，出現:贅詞，3.1502562e-13
# 2分50.75秒，出現:贅詞，4.0986e-11
# 2分51.0秒，出現:贅詞，1.8402342e-11
# 2分51.25秒，出現:贅詞，3.6826497e-11
# 2分51.5秒，出現:贅詞，3.6678847e-09
# 2分51.75秒，出現:贅詞，1.8415697e-09
# 2分52.0秒，出現:贅詞，4.020719e-12
# 2分52.25秒，出現:贅詞，1.3342118e-10
# 2分52.5秒，出現:贅詞，2.2669768e-09
# 2分52.75秒，出現:贅詞，5.719518e-10
# 2分53.0秒，出現:贅詞，2.641557e-10
# 2分53.25秒，出現:贅詞，2.086669e-12
# 2分53.5秒，出現:贅詞，3.0804164e-16
# 2分53.75秒，出現:贅詞，4.748324e-14
# 2分54.0秒，出現:贅詞，5.5789956e-10
# 2分54.25秒，出現:贅詞，2.6442844e-08
# 2分54.5秒，出現:贅詞，1.5911095e-08
# 2分54.75秒，出現:贅詞，6.7985957e-07
# 2分55.0秒，出現:贅詞，2.0504136e-05
# 2分55.25秒，出現:贅詞，1.6610637e-05
# 2分55.5秒，出現:贅詞，4.1897714e-05
# 2分55.75秒，出現:贅詞，1.1203958e-05
# 2分56.0秒，出現:贅詞，0.0001374587
# 2分56.25秒，出現:贅詞，0.00073049637
# 2分56.5秒，出現:贅詞，0.0006421374
# 2分56.75秒，出現:贅詞，0.00060663756
# 2分57.0秒，出現:贅詞，0.0005946659
# 2分57.25秒，出現:贅詞，0.00016580387
# 2分57.5秒，出現:贅詞，0.00040212244
# 2分57.75秒，出現:贅詞，0.0007882063
# 2分58.0秒，出現:贅詞，0.001471022
# 2分58.25秒，出現:贅詞，0.0006526283
# 2分58.5秒，出現:贅詞，0.00083164306
# 2分58.75秒，出現:贅詞，0.0003787334
# 2分59.0秒，出現:贅詞，2.4415513e-05
# 2分59.25秒，出現:贅詞，1.4920725e-05
# 2分59.5秒，出現:贅詞，2.2821563e-05
# 2分59.75秒，出現:贅詞，0.00025216595
# 3分0秒，出現:贅詞，0.0006695952
# 720

# %%
#slide_window=0.25
import sounddevice as sd
import numpy as np
import scipy.signal
import python_speech_features
import tensorflow as tf
from PyQt5.QtCore import QTime
import librosa

# This gets called every 0.5 seconds
def sound(window,s,m):
    
    S = np.abs(librosa.stft(window)) #將整個window音訊做stft，並轉成絕對值
    
    if np.sum(S) > 3000: #判斷S的總和是否>3000，如果>3000，代表有講話
        # Compute features
        mfccs = python_speech_features.base.mfcc(window, #輸入訊號
                                            samplerate=8000, #取樣率
                                            winlen=0.256, #音框涵蓋時間
                                            winstep=0.050, #音框間距離
                                            numcep=num_mfcc, #返回係數的量
                                            nfilt=26, #過濾器數量
                                            nfft=2048,#FFT大小
                                            preemph=0.0,#不用預強化濾波器
                                            ceplifter=0,#ROBUST
                                            appendEnergy=True,#True的話，第0個倒頻譜係數被替代成總音框能量的對數
                                            winfunc=np.hanning)#hanning window
        mfccs = mfccs.transpose()
        
        # Make prediction from model
        in_tensor = np.float32(mfccs.reshape(1, mfccs.shape[0], mfccs.shape[1], 1))
        #設定輸入張量
        interpreter.set_tensor(input_details[0]['index'], in_tensor)
        #進行預測
        interpreter.invoke()
        #取得輸出張量
        output_data = interpreter.get_tensor(output_details[0]['index'])
        
        val = output_data[0]#取得預測值
        val = val.tolist() #np.ndarray to list
        list_val_max = max(val) #取得最大值
        list_val_maxIndex = val.index(max(val)) #取得最大值的索引  
        
        if list_val_max >= 0.8 and list_val_max < 0.9:
   #data_ho.append(str(m) + "分" + str(s) + "秒，出現:" + str(words[list_val_maxIndex]) + "，預測值:" + str(list_val_max))
             data.append(str(m) + "分" + str(s) + "秒，出現:" + str(words[list_val_maxIndex]) + "，預測值:" + str(list_val_max))
           # data.append(str(list_val_max))
         
#main
# Parameters
num_mfcc = 23 #回傳mfcc的量
model_path = './tflite/appendEnergyTT_wen.tflite'
words = ['backgroundNoise', 'ㄏㄧㄡ', 'ㄟ', '他', '你', '吼', '啦', '嗯', '好', '我', '的', '的一個', '的這個', '的那個', '著', '那', '那那個', '阿']#答案對應到的字詞
data = []
data_ho = []
start = 0 #一開始的索引值
end = 2000 #一開始的索引值
s = 0 #秒
m = 0 #分
duration = 180 #讀音檔的總時間
sample_rate = 8000 #取樣率

#載入音檔
y, sr = librosa.load("./desktop/chen2.wav",sr=sample_rate,duration=duration) 

# Sliding window
window = np.zeros(8000)#取樣音頻數據變數

# Load model (interpreter)
interpreter = tf.lite.Interpreter(model_path)
interpreter.allocate_tensors()
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()


while True:
    s = s + 0.25 #增加秒數
    if(s == 60): #60秒 轉成 1分
        s = 0
        m = m + 1

    #window[:4000] = window[4000:] #把音訊載入window
    #window[4000:] = y[start:end] #把音訊載入window
    window[0:2000] = window[2000:4000]
    window[2000:4000] = window[4000:6000]
    window[4000:6000] = window[6000:8000]
    window[6000:8000] = y[start:end]
    sound(window,s,m) #呼叫sound()

    if(end == (8000 * duration)): #如果移動到最後，break
        break
    
    start = start + 2000 #向後移動
    end = end + 2000 #向後移動    
    
    
for i in range(len(data)):
        print(data[i])
        
print("總共:",len(data))
# Out:
# 0分1.0秒，出現:你，預測值:0.8144705891609192
# 0分3.25秒，出現:我，預測值:0.8558109998703003
# 0分4.0秒，出現:那，預測值:0.8609471917152405
# 0分4.5秒，出現:的一個，預測值:0.8529371619224548
# 0分5.25秒，出現:我，預測值:0.8732877969741821
# 0分10.75秒，出現:我，預測值:0.8623384237289429
# 0分12.25秒，出現:我，預測值:0.8259959816932678
# 0分13.25秒，出現:你，預測值:0.8380088806152344
# 0分14.75秒，出現:的一個，預測值:0.8247097730636597
# 0分15.0秒，出現:的這個，預測值:0.8152815699577332
# 0分17.5秒，出現:我，預測值:0.8642467260360718
# 0分19.5秒，出現:你，預測值:0.8537974953651428
# 0分22.25秒，出現:ㄟ，預測值:0.8161870241165161
# 0分22.75秒，出現:你，預測值:0.8976947069168091
# 0分29.0秒，出現:我，預測值:0.8791391849517822
# 0分30.5秒，出現:的一個，預測值:0.8202406167984009
# 0分30.75秒，出現:你，預測值:0.8615965843200684
# 0分32.75秒，出現:我，預測值:0.813188374042511
# 0分33.0秒，出現:我，預測值:0.8136052489280701
# 0分33.5秒，出現:我，預測值:0.8641261458396912
# 0分36.25秒，出現:你，預測值:0.8368300795555115
# 0分37.5秒，出現:的這個，預測值:0.8052206635475159
# 0分37.75秒，出現:你，預測值:0.8632212281227112
# 0分42.75秒，出現:我，預測值:0.8972828984260559
# 0分43.0秒，出現:我，預測值:0.840818464756012
# 0分49.5秒，出現:ㄟ，預測值:0.8279343843460083
# 0分49.75秒，出現:我，預測值:0.8911739587783813
# 0分54.5秒，出現:你，預測值:0.8952180743217468
# 0分55.0秒，出現:我，預測值:0.8486714363098145
# 0分58.75秒，出現:的這個，預測值:0.80811607837677
# 1分0.25秒，出現:我，預測值:0.8765104413032532
# 1分10.5秒，出現:我，預測值:0.8878377676010132
# 1分10.75秒，出現:你，預測值:0.872597873210907
# 1分18.5秒，出現:的這個，預測值:0.8257237672805786
# 1分24.25秒，出現:我，預測值:0.8408409953117371
# 1分27.0秒，出現:那，預測值:0.8186233639717102
# 1分32.5秒，出現:ㄟ，預測值:0.8225575685501099
# 1分35.5秒，出現:我，預測值:0.8478077054023743
# 1分38.0秒，出現:的一個，預測值:0.8738768696784973
# 1分41.0秒，出現:的一個，預測值:0.8409692645072937
# 1分41.25秒，出現:我，預測值:0.806602954864502
# 1分42.25秒，出現:我，預測值:0.8316763639450073
# 1分42.75秒，出現:我，預測值:0.8251761794090271
# 1分43.0秒，出現:阿，預測值:0.8695135712623596
# 1分43.5秒，出現:的這個，預測值:0.8631237149238586
# 1分45.0秒，出現:我，預測值:0.8226375579833984
# 2分4.5秒，出現:那那個，預測值:0.8279010653495789
# 2分8.75秒，出現:我，預測值:0.8515380620956421
# 2分11.25秒，出現:我，預測值:0.8843969106674194
# 2分11.75秒，出現:你，預測值:0.8236773014068604
# 2分13.25秒，出現:的一個，預測值:0.8891469240188599
# 2分14.5秒，出現:你，預測值:0.8846501111984253
# 2分15.0秒，出現:我，預測值:0.86119544506073
# 2分16.25秒，出現:我，預測值:0.8271406292915344
# 2分19.0秒，出現:我，預測值:0.8829801678657532
# 2分21.75秒，出現:我，預測值:0.8911334276199341
# 2分23.0秒，出現:你，預測值:0.8522931933403015
# 2分28.5秒，出現:我，預測值:0.8929935097694397
# 2分29.0秒，出現:的一個，預測值:0.8981503248214722
# 2分29.25秒，出現:的一個，預測值:0.8661014437675476
# 2分33.25秒，出現:我，預測值:0.8765357136726379
# 2分35.0秒，出現:你，預測值:0.8504707217216492
# 2分37.75秒，出現:我，預測值:0.872922956943512
# 2分39.25秒，出現:我，預測值:0.849187970161438
# 2分45.0秒，出現:的，預測值:0.8386000990867615
# 2分45.25秒，出現:的一個，預測值:0.8078205585479736
# 2分48.0秒，出現:我，預測值:0.8882989883422852
# 2分48.25秒，出現:你，預測值:0.813084065914154
# 2分48.5秒，出現:的一個，預測值:0.8877003788948059
# 2分48.75秒，出現:的一個，預測值:0.8856552839279175
# 2分57.75秒，出現:嗯，預測值:0.8622407913208008
# 總共: 71
