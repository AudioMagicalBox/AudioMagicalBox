# %%
import sounddevice as sd
import numpy as np
import scipy.signal
import python_speech_features
import tensorflow as tf
from PyQt5.QtCore import QTime
import librosa

# This gets called every 0.5 seconds
def sound(window,s,m):
    
    S = np.abs(librosa.stft(window)) #將整個window音訊做stft，並轉成絕對值
    
    if np.sum(S) >= 500: #判斷S的總和是否>500，如果>500，代表有明顯的聲音
        # Compute features
        mfccs = python_speech_features.base.mfcc(window, #輸入訊號
                                            samplerate=sample_rate, #取樣率
                                            winlen=0.025, #音框涵蓋時間(s)
                                            winstep=0.01, #音框間的時間(s)
                                            numcep=num_mfcc, #返回係數的量
                                            nfilt=26, #過濾器數量
                                            nfft=512, #FFT大小
                                            lowfreq=0, #lowest band edge of mel filters. 
                                            highfreq=None, #highest band edge of mel filters. 
                                            preemph=0.97, #不用預強化濾波器
                                            ceplifter=22, #robust
                                            appendEnergy=True, #True的話，第0個倒頻譜係數被替代成總音框能量的對數
                                            winfunc=np.hanning) #漢明窗，增加音框左右端連續性(在進行 FFT 時，都是假設一個音框內的訊號是代表一個週期性訊號，如果這個週期性不存在，FFT 會為了要符合左右端不連續的變化，而產生一些不存在原訊號的能量分佈，造成分析上的誤差。)
       
        mfccs = mfccs.transpose()
        
        # Make prediction from model
        in_tensor = np.float32(mfccs.reshape(1, mfccs.shape[0], mfccs.shape[1], 1))
        #設定輸入張量
        interpreter.set_tensor(input_details[0]['index'], in_tensor)
        #進行預測
        interpreter.invoke()
        #取得輸出張量
        output_data = interpreter.get_tensor(output_details[0]['index'])
        
        val = output_data[0]#取得預測值
        val = val.tolist() #np.ndarray to list
        list_val_max = max(val) #取得最大值
        list_val_maxIndex = val.index(max(val)) #取得最大值的索引  
        
        if list_val_max >= 0.5:
            data.append(str(m) + "分" + str(s) + "秒，出現:" + str(words[list_val_maxIndex]) + "，預測值:" + str(list_val_max))
            if list_val_maxIndex == 5:
                data_ho.append(str(m) + "分" + str(s) + "秒，出現:" + str(words[list_val_maxIndex]) + "，預測值:" + str(list_val_max))
#main
# Parameters
num_mfcc = 13 #回傳mfcc的量
model_path = './tflite/recordingSpecAugment.tflite'
words = ['backgroundNoise', 'ㄏㄧㄡ', 'ㄟ', '他', '你', '吼', '啦', '嗯', '好', '我', '的', '的一個', '的這個', '的那個', '著', '那', '那那個', '阿']
data = []
data_ho = []
start = 0 #一開始的索引值
end = 4000 #一開始的索引值
s = 0 #秒
m = 0 #分
duration = 180 #讀音檔的總時間
sample_rate = 16000 #取樣率

#載入音檔
y, sr = librosa.load("./TestWAV/chen16000.wav",sr=sample_rate,duration=duration) 

# Sliding window
window = np.zeros(8000)#取樣音頻數據變數

# Load model (interpreter)
interpreter = tf.lite.Interpreter(model_path)
interpreter.allocate_tensors()
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()


while True:
    s = s + 0.25 #增加秒數
    if(s == 60): #60秒 轉成 1分
        s = 0
        m = m + 1

    window[:4000] = window[4000:] #把音訊載入window
    window[4000:] = y[start:end] #把音訊載入window
    
    sound(window,s,m) #呼叫sound()

    if(end == (16000 * duration)): #如果移動到最後，break
        break
    
    start = start + 4000 #向後移動
    end = end + 4000 #向後移動    
    
    
for i in range(len(data)):
        print(data[i])
# Out:
# 0分1.0秒，出現:那那個，預測值:0.5835652947425842
# 0分1.5秒，出現:那那個，預測值:0.8519333004951477
# 0分1.75秒，出現:的這個，預測值:0.9202089309692383
# 0分2.0秒，出現:我，預測值:0.9902154207229614
# 0分2.5秒，出現:的這個，預測值:0.974177360534668
# 0分2.75秒，出現:你，預測值:0.9404621124267578
# 0分3.0秒，出現:ㄟ，預測值:0.7590228915214539
# 0分3.25秒，出現:那那個，預測值:0.6693817973136902
# 0分3.5秒，出現:你，預測值:0.9938269257545471
# 0分4.0秒，出現:我，預測值:0.9191387295722961
# 0分4.25秒，出現:那那個，預測值:0.9839852452278137
# 0分4.5秒，出現:的這個，預測值:0.8836773037910461
# 0分4.75秒，出現:那那個，預測值:0.9882999658584595
# 0分5.0秒，出現:那那個，預測值:0.5756126642227173
# 0分5.75秒，出現:嗯，預測值:0.6590007543563843
# 0分6.0秒，出現:backgroundNoise，預測值:0.6092184782028198
# 0分6.25秒，出現:你，預測值:0.7965297698974609
# 0分6.5秒，出現:你，預測值:0.9762486815452576
# 0分6.75秒，出現:我，預測值:0.8032112121582031
# 0分7.0秒，出現:那那個，預測值:0.602057695388794
# 0分7.25秒，出現:那那個，預測值:0.5926369428634644
# 0分7.5秒，出現:你，預測值:0.9718568921089172
# 0分7.75秒，出現:你，預測值:0.5159481167793274
# 0分8.0秒，出現:你，預測值:0.9474757313728333
# 0分8.25秒，出現:的這個，預測值:0.7514978647232056
# 0分8.5秒，出現:你，預測值:0.6209661960601807
# 0分8.75秒，出現:的一個，預測值:0.7905459403991699
# 0分9.0秒，出現:那那個，預測值:0.8515336513519287
# 0分9.25秒，出現:那那個，預測值:0.5522910952568054
# 0分9.5秒，出現:你，預測值:0.9484990239143372
# 0分9.75秒，出現:你，預測值:0.8427844047546387
# 0分10.0秒，出現:你，預測值:0.6765244603157043
# 0分10.25秒，出現:的這個，預測值:0.7923680543899536
# 0分10.5秒，出現:的這個，預測值:0.7071453928947449
# 0分10.75秒，出現:那那個，預測值:0.8124780058860779
# 0分11.25秒，出現:你，預測值:0.7317691445350647
# 0分11.5秒，出現:你，預測值:0.7560696601867676
# 0分11.75秒，出現:你，預測值:0.998281717300415
# 0分12.0秒，出現:那，預測值:0.5785086154937744
# 0分12.25秒，出現:你，預測值:0.9818933010101318
# 0分12.5秒，出現:你，預測值:0.998050332069397
# 0分12.75秒，出現:的這個，預測值:0.9744971394538879
# 0分13.0秒，出現:你，預測值:0.9195311069488525
# 0分13.25秒，出現:你，預測值:0.8878045678138733
# 0分13.5秒，出現:你，預測值:0.8553216457366943
# 0分14.0秒，出現:的這個，預測值:0.6400789022445679
# 0分14.5秒，出現:嗯，預測值:0.5141869783401489
# 0分14.75秒，出現:的一個，預測值:0.9774609804153442
# 0分15.0秒，出現:那那個，預測值:0.7862849831581116
# 0分15.75秒，出現:你，預測值:0.9717735648155212
# 0分16.0秒，出現:那那個，預測值:0.7134537696838379
# 0分16.25秒，出現:嗯，預測值:0.5046509504318237
# 0分16.5秒，出現:那那個，預測值:0.7927058339118958
# 0分16.75秒，出現:你，預測值:0.873772919178009
# 0分17.0秒，出現:你，預測值:0.9211882948875427
# 0分17.25秒，出現:ㄟ，預測值:0.7728847861289978
# 0分17.5秒，出現:那那個，預測值:0.9898191094398499
# 0分17.75秒，出現:的一個，預測值:0.5892828106880188
# 0分18.0秒，出現:你，預測值:0.5069597363471985
# 0分18.25秒，出現:你，預測值:0.9882331490516663
# 0分18.5秒，出現:你，預測值:0.8841398358345032
# 0分18.75秒，出現:的這個，預測值:0.6181406378746033
# 0分19.0秒，出現:你，預測值:0.9955533146858215
# 0分19.25秒，出現:你，預測值:0.9493018388748169
# 0分19.5秒，出現:你，預測值:0.9809733033180237
# 0分19.75秒，出現:你，預測值:0.9891632795333862
# 0分20.0秒，出現:你，預測值:0.7685890197753906
# 0分20.25秒，出現:你，預測值:0.9178637266159058
# 0分20.5秒，出現:你，預測值:0.8388628363609314
# 0分20.75秒，出現:的一個，預測值:0.8323110342025757
# 0分21.0秒，出現:的這個，預測值:0.9331679940223694
# 0分21.5秒，出現:你，預測值:0.6131905913352966
# 0分21.75秒，出現:你，預測值:0.9159479737281799
# 0分22.0秒，出現:你，預測值:0.5705935955047607
# 0分22.25秒，出現:的這個，預測值:0.9308891296386719
# 0分22.5秒，出現:你，預測值:0.9886387586593628
# 0分22.75秒，出現:你，預測值:0.9755510091781616
# 0分23.0秒，出現:那那個，預測值:0.8149463534355164
# 0分23.25秒，出現:嗯，預測值:0.5680705308914185
# 0分23.5秒，出現:你，預測值:0.9428125619888306
# 0分23.75秒，出現:那那個，預測值:0.8429701924324036
# 0分24.0秒，出現:那那個，預測值:0.619775116443634
# 0分24.25秒，出現:你，預測值:0.8678869605064392
# 0分24.5秒，出現:那那個，預測值:0.833185076713562
# 0分24.75秒，出現:的一個，預測值:0.8720095157623291
# 0分25.25秒，出現:ㄟ，預測值:0.8246999382972717
# 0分25.5秒，出現:那那個，預測值:0.9889646768569946
# 0分26.0秒，出現:你，預測值:0.9059311151504517
# 0分26.25秒，出現:你，預測值:0.995290994644165
# 0分26.5秒，出現:那那個，預測值:0.7475501894950867
# 0分26.75秒，出現:你，預測值:0.9797942042350769
# 0分27.0秒，出現:你，預測值:0.9353756904602051
# 0分27.5秒，出現:那，預測值:0.864890992641449
# 0分27.75秒，出現:嗯，預測值:0.6905251741409302
# 0分28.25秒，出現:那那個，預測值:0.6558088064193726
# 0分28.5秒，出現:那，預測值:0.5618895888328552
# 0分28.75秒，出現:你，預測值:0.5670990347862244
# 0分29.0秒，出現:ㄟ，預測值:0.7727961540222168
# 0分29.25秒，出現:你，預測值:0.9979876279830933
# 0分29.5秒，出現:我，預測值:0.8693317174911499
# 0分29.75秒，出現:你，預測值:0.6925344467163086
# 0分30.0秒，出現:你，預測值:0.738210141658783
# 0分30.25秒，出現:你，預測值:0.9868512749671936
# 0分30.5秒，出現:你，預測值:0.8970381021499634
# 0分30.75秒，出現:那那個，預測值:0.9593827724456787
# 0分31.0秒，出現:你，預測值:0.977348804473877
# 0分31.25秒，出現:你，預測值:0.9966719150543213
# 0分31.5秒，出現:的一個，預測值:0.9061487913131714
# 0分31.75秒，出現:那那個，預測值:0.7424387335777283
# 0分32.0秒，出現:他，預測值:0.7290210127830505
# 0分32.25秒，出現:那那個，預測值:0.8085331916809082
# 0分32.5秒，出現:那那個，預測值:0.6091340780258179
# 0分32.75秒，出現:你，預測值:0.550092875957489
# 0分33.0秒，出現:你，預測值:0.7275488376617432
# 0分33.25秒，出現:那那個，預測值:0.6008424758911133
# 0分33.5秒，出現:的一個，預測值:0.7570582628250122
# 0分34.25秒，出現:你，預測值:0.6099222898483276
# 0分34.5秒，出現:你，預測值:0.9763860702514648
# 0分34.75秒，出現:的這個，預測值:0.5149351954460144
# 0分35.0秒，出現:你，預測值:0.9720141887664795
# 0分35.5秒，出現:那那個，預測值:0.70687335729599
# 0分35.75秒，出現:的這個，預測值:0.781595766544342
# 0分36.0秒，出現:那那個，預測值:0.8823268413543701
# 0分36.25秒，出現:的一個，預測值:0.9915761351585388
# 0分36.5秒，出現:的一個，預測值:0.9365671277046204
# 0分36.75秒，出現:的這個，預測值:0.9348066449165344
# 0分37.0秒，出現:的一個，預測值:0.7734735012054443
# 0分37.5秒，出現:的這個，預測值:0.7205455899238586
# 0分37.75秒，出現:ㄟ，預測值:0.879806637763977
# 0分38.0秒，出現:你，預測值:0.8700531721115112
# 0分38.25秒，出現:那那個，預測值:0.6073557138442993
# 0分38.5秒，出現:那那個，預測值:0.9804819226264954
# 0分38.75秒，出現:的一個，預測值:0.6331554651260376
# 0分39.0秒，出現:嗯，預測值:0.7709376215934753
# 0分39.25秒，出現:的一個，預測值:0.5559029579162598
# 0分39.5秒，出現:的這個，預測值:0.5787477493286133
# 0分39.75秒，出現:的這個，預測值:0.6719725131988525
# 0分40.25秒，出現:那那個，預測值:0.9089257717132568
# 0分40.5秒，出現:那那個，預測值:0.9083163142204285
# 0分41.0秒，出現:你，預測值:0.8558487296104431
# 0分41.25秒，出現:你，預測值:0.5860912203788757
# 0分41.5秒，出現:你，預測值:0.686022937297821
# 0分41.75秒，出現:backgroundNoise，預測值:0.9147256016731262
# 0分42.0秒，出現:阿，預測值:0.5492621064186096
# 0分42.25秒，出現:那那個，預測值:0.7450189590454102
# 0分42.5秒，出現:那那個，預測值:0.9724306464195251
# 0分43.0秒，出現:你，預測值:0.9677161574363708
# 0分43.25秒，出現:你，預測值:0.9991900324821472
# 0分43.5秒，出現:你，預測值:0.9539358019828796
# 0分43.75秒，出現:你，預測值:0.9270763993263245
# 0分44.25秒，出現:你，預測值:0.9976892471313477
# 0分44.5秒，出現:你，預測值:0.586982786655426
# 0分44.75秒，出現:的一個，預測值:0.9815787076950073
# 0分45.0秒，出現:那那個，預測值:0.5026508569717407
# 0分45.5秒，出現:的這個，預測值:0.9815094470977783
# 0分45.75秒，出現:的一個，預測值:0.8821535706520081
# 0分46.0秒，出現:那那個，預測值:0.8533920049667358
# 0分47.75秒，出現:那那個，預測值:0.7571313381195068
# 0分48.0秒，出現:那那個，預測值:0.7374057173728943
# 0分48.25秒，出現:backgroundNoise，預測值:0.9962739944458008
# 0分48.5秒，出現:你，預測值:0.8595539331436157
# 0分49.0秒，出現:我，預測值:0.7232648134231567
# 0分50.25秒，出現:那那個，預測值:0.6487493515014648
# 0分50.75秒，出現:的這個，預測值:0.9176719188690186
# 0分51.0秒，出現:你，預測值:0.9742549657821655
# 0分51.25秒，出現:我，預測值:0.9292037487030029
# 0分51.5秒，出現:那那個，預測值:0.7871556878089905
# 0分51.75秒，出現:你，預測值:0.6081095337867737
# 0分52.0秒，出現:那那個，預測值:0.8630861639976501
# 0分52.25秒，出現:你，預測值:0.5362553596496582
# 0分52.5秒，出現:backgroundNoise，預測值:0.9429458975791931
# 0分52.75秒，出現:你，預測值:0.8242478966712952
# 0分53.0秒，出現:你，預測值:0.8664167523384094
# 0分53.5秒，出現:嗯，預測值:0.7544597387313843
# 0分53.75秒，出現:的一個，預測值:0.8217646479606628
# 0分54.0秒，出現:那那個，預測值:0.7028960585594177
# 0分54.25秒，出現:的這個，預測值:0.7898899912834167
# 0分54.5秒，出現:backgroundNoise，預測值:0.6090338230133057
# 0分54.75秒，出現:你，預測值:0.5796764492988586
# 0分55.25秒，出現:你，預測值:0.7909537553787231
# 0分55.5秒，出現:的這個，預測值:0.8609145283699036
# 0分55.75秒，出現:你，預測值:0.6104961037635803
# 0分56.0秒，出現:backgroundNoise，預測值:0.9017975330352783
# 0分56.25秒，出現:你，預測值:0.9873787760734558
# 0分56.5秒，出現:backgroundNoise，預測值:0.5284868478775024
# 0分56.75秒，出現:那那個，預測值:0.9780584573745728
# 0分57.0秒，出現:ㄟ，預測值:0.72628253698349
# 0分57.25秒，出現:你，預測值:0.9817484021186829
# 0分57.5秒，出現:你，預測值:0.9998570680618286
# 0分57.75秒，出現:的一個，預測值:0.9901188611984253
# 0分58.0秒，出現:你，預測值:0.9619826674461365
# 0分58.25秒，出現:你，預測值:0.8520869612693787
# 0分58.5秒，出現:你，預測值:0.9850391149520874
# 0分58.75秒，出現:那那個，預測值:0.5244333744049072
# 0分59.25秒，出現:那那個，預測值:0.9793844223022461
# 0分59.75秒，出現:你，預測值:0.9921865463256836
# 1分0秒，出現:你，預測值:0.6973872780799866
# 1分0.25秒，出現:你，預測值:0.886236310005188
# 1分0.5秒，出現:那那個，預測值:0.8864867687225342
# 1分0.75秒，出現:你，預測值:0.5576887726783752
# 1分1.25秒，出現:那那個，預測值:0.8351633548736572
# 1分1.5秒，出現:你，預測值:0.7422428131103516
# 1分1.75秒，出現:你，預測值:0.9360735416412354
# 1分2.0秒，出現:那那個，預測值:0.9108685255050659
# 1分2.25秒，出現:你，預測值:0.9885718822479248
# 1分2.5秒，出現:的一個，預測值:0.5941095948219299
# 1分2.75秒，出現:的一個，預測值:0.8851704597473145
# 1分3.0秒，出現:的這個，預測值:0.9871435761451721
# 1分3.25秒，出現:你，預測值:0.8598949313163757
# 1分3.5秒，出現:你，預測值:0.6610718965530396
# 1分3.75秒，出現:的那個，預測值:0.8518476486206055
# 1分4.0秒，出現:那那個，預測值:0.9430586099624634
# 1分4.5秒，出現:嗯，預測值:0.502204179763794
# 1分6.25秒，出現:那那個，預測值:0.9028190970420837
# 1分6.75秒，出現:那那個，預測值:0.7631662487983704
# 1分7.0秒，出現:的這個，預測值:0.642404317855835
# 1分7.25秒，出現:backgroundNoise，預測值:0.997134804725647
# 1分7.75秒，出現:你，預測值:0.6903752684593201
# 1分8.25秒，出現:你，預測值:0.88528972864151
# 1分9.0秒，出現:你，預測值:0.7680836319923401
# 1分9.25秒，出現:ㄟ，預測值:0.6860127449035645
# 1分10.0秒，出現:那那個，預測值:0.9551965594291687
# 1分10.25秒，出現:那那個，預測值:0.6512105464935303
# 1分10.75秒，出現:那那個，預測值:0.8015748858451843
# 1分11.0秒，出現:ㄟ，預測值:0.6020386815071106
# 1分11.5秒，出現:的這個，預測值:0.7913727164268494
# 1分12.0秒，出現:那，預測值:0.5751585960388184
# 1分12.75秒，出現:那那個，預測值:0.7407647371292114
# 1分13.25秒，出現:的一個，預測值:0.9314948916435242
# 1分13.5秒，出現:ㄟ，預測值:0.6454133987426758
# 1分13.75秒，出現:你，預測值:0.6929988265037537
# 1分14.0秒，出現:我，預測值:0.8333600163459778
# 1分14.25秒，出現:的這個，預測值:0.9833762049674988
# 1分14.5秒，出現:那那個，預測值:0.6572018265724182
# 1分15.25秒，出現:那那個，預測值:0.7148563265800476
# 1分15.5秒，出現:那那個，預測值:0.9855557680130005
# 1分15.75秒，出現:的一個，預測值:0.8359336256980896
# 1分16.0秒，出現:的這個，預測值:0.693439245223999
# 1分16.25秒，出現:那那個，預測值:0.9623656868934631
# 1分17.0秒，出現:你，預測值:0.6296706199645996
# 1分17.25秒，出現:你，預測值:0.7955015301704407
# 1分17.5秒，出現:你，預測值:0.8992612957954407
# 1分17.75秒，出現:的這個，預測值:0.9685571789741516
# 1分18.0秒，出現:那那個，預測值:0.9619947671890259
# 1分18.25秒，出現:那那個，預測值:0.6679903268814087
# 1分18.5秒，出現:好，預測值:0.505463719367981
# 1分18.75秒，出現:那那個，預測值:0.6847664713859558
# 1分19.25秒，出現:你，預測值:0.6886153221130371
# 1分19.5秒，出現:那那個，預測值:0.6848007440567017
# 1分19.75秒，出現:那那個，預測值:0.8682915568351746
# 1分20.0秒，出現:你，預測值:0.6088612675666809
# 1分20.25秒，出現:那，預測值:0.8714306950569153
# 1分20.75秒，出現:那，預測值:0.8824500441551208
# 1分21.0秒，出現:的一個，預測值:0.791573166847229
# 1分21.25秒，出現:的這個，預測值:0.9655394554138184
# 1分21.75秒，出現:你，預測值:0.9711341261863708
# 1分22.0秒，出現:那那個，預測值:0.9799365997314453
# 1分22.5秒，出現:ㄟ，預測值:0.5619727373123169
# 1分23.25秒，出現:的這個，預測值:0.672742486000061
# 1分23.5秒，出現:嗯，預測值:0.684175968170166
# 1分23.75秒，出現:你，預測值:0.7515650987625122
# 1分24.0秒，出現:你，預測值:0.8261613845825195
# 1分24.25秒，出現:我，預測值:0.7927594780921936
# 1分24.5秒，出現:你，預測值:0.6888595223426819
# 1分24.75秒，出現:的一個，預測值:0.7980220317840576
# 1分25.0秒，出現:我，預測值:0.9991753697395325
# 1分25.5秒，出現:那那個，預測值:0.8910151124000549
# 1分26.0秒，出現:backgroundNoise，預測值:0.7368006706237793
# 1分26.25秒，出現:你，預測值:0.9738015532493591
# 1分26.5秒，出現:backgroundNoise，預測值:0.9397966265678406
# 1分26.75秒，出現:你，預測值:0.9727869033813477
# 1分27.0秒，出現:的這個，預測值:0.5239764451980591
# 1分27.5秒，出現:你，預測值:0.9904202818870544
# 1分27.75秒，出現:你，預測值:0.967228353023529
# 1分28.0秒，出現:你，預測值:0.9816548824310303
# 1分28.75秒，出現:的這個，預測值:0.9200509786605835
# 1分29.25秒，出現:的這個，預測值:0.5461944341659546
# 1分29.5秒，出現:的這個，預測值:0.990348219871521
# 1分29.75秒，出現:你，預測值:0.9458179473876953
# 1分30.0秒，出現:的這個，預測值:0.5805202126502991
# 1分30.25秒，出現:那，預測值:0.9115753173828125
# 1分30.5秒，出現:那那個，預測值:0.9204603433609009
# 1分31.0秒，出現:的這個，預測值:0.6219323873519897
# 1分31.25秒，出現:的這個，預測值:0.5538032054901123
# 1分31.5秒，出現:你，預測值:0.533580482006073
# 1分31.75秒，出現:的一個，預測值:0.8658555746078491
# 1分32.0秒，出現:你，預測值:0.8506715297698975
# 1分32.25秒，出現:你，預測值:0.9839275479316711
# 1分32.5秒，出現:你，預測值:0.9184011220932007
# 1分32.75秒，出現:backgroundNoise，預測值:0.5839529633522034
# 1分33.0秒，出現:的一個，預測值:0.6762452721595764
# 1分33.25秒，出現:你，預測值:0.919937252998352
# 1分33.5秒，出現:你，預測值:0.9666464328765869
# 1分33.75秒，出現:那那個，預測值:0.9708874225616455
# 1分34.0秒，出現:你，預測值:0.8917614221572876
# 1分34.25秒，出現:你，預測值:0.965495228767395
# 1分34.5秒，出現:的一個，預測值:0.7587587833404541
# 1分35.0秒，出現:我，預測值:0.7776747345924377
# 1分35.25秒，出現:的這個，預測值:0.9777514934539795
# 1分35.5秒，出現:的一個，預測值:0.9684810638427734
# 1分35.75秒，出現:那那個，預測值:0.6660273671150208
# 1分36.25秒，出現:ㄟ，預測值:0.5838741064071655
# 1分36.75秒，出現:的一個，預測值:0.6042977571487427
# 1分37.0秒，出現:的這個，預測值:0.9217050075531006
# 1分37.25秒，出現:你，預測值:0.6355504989624023
# 1分37.75秒，出現:的一個，預測值:0.6588501930236816
# 1分38.0秒，出現:好，預測值:0.9382657408714294
# 1分38.25秒，出現:你，預測值:0.5347050428390503
# 1分38.75秒，出現:你，預測值:0.70583575963974
# 1分39.0秒，出現:的這個，預測值:0.8303996324539185
# 1分39.25秒，出現:你，預測值:0.9967325925827026
# 1分39.5秒，出現:的這個，預測值:0.5196840763092041
# 1分39.75秒，出現:的一個，預測值:0.9530283808708191
# 1分40.25秒，出現:的那個，預測值:0.5937875509262085
# 1分40.5秒，出現:好，預測值:0.8313668370246887
# 1分40.75秒，出現:的一個，預測值:0.9239853620529175
# 1分41.0秒，出現:ㄟ，預測值:0.536925196647644
# 1分41.25秒，出現:那那個，預測值:0.8990954160690308
# 1分41.5秒，出現:你，預測值:0.5583521723747253
# 1分41.75秒，出現:你，預測值:0.9483175873756409
# 1分42.0秒，出現:的一個，預測值:0.833946168422699
# 1分42.5秒，出現:你，預測值:0.9512534141540527
# 1分42.75秒，出現:那那個，預測值:0.9658999443054199
# 1分43.25秒，出現:那那個，預測值:0.9513437747955322
# 1分43.5秒，出現:的一個，預測值:0.7084709405899048
# 1分43.75秒，出現:嗯，預測值:0.6775143146514893
# 1分44.25秒，出現:你，預測值:0.9859523773193359
# 1分44.5秒，出現:你，預測值:0.9256949424743652
# 1分44.75秒，出現:嗯，預測值:0.6571717858314514
# 1分45.5秒，出現:你，預測值:0.8698385953903198
# 1分45.75秒，出現:的一個，預測值:0.6936155557632446
# 1分46.0秒，出現:的這個，預測值:0.7516417503356934
# 1分46.25秒，出現:你，預測值:0.5624299049377441
# 1分46.5秒，出現:你，預測值:0.5939785838127136
# 1分46.75秒，出現:的這個，預測值:0.9134941101074219
# 1分47.0秒，出現:的一個，預測值:0.6185370087623596
# 1分47.25秒，出現:你，預測值:0.9612630605697632
# 1分47.5秒，出現:的一個，預測值:0.8297304511070251
# 1分47.75秒，出現:的這個，預測值:0.7685009837150574
# 1分48.0秒，出現:你，預測值:0.7911855578422546
# 1分48.25秒，出現:的這個，預測值:0.5137296319007874
# 1分48.5秒，出現:你，預測值:0.8155685663223267
# 1分48.75秒，出現:的這個，預測值:0.5056433081626892
# 1分49.0秒，出現:那那個，預測值:0.7968789935112
# 1分49.25秒，出現:的這個，預測值:0.9372779130935669
# 1分49.5秒，出現:那那個，預測值:0.6675169467926025
# 1分49.75秒，出現:那那個，預測值:0.9278426766395569
# 1分50.0秒，出現:我，預測值:0.9751284718513489
# 1分50.25秒，出現:那那個，預測值:0.5891326665878296
# 1分50.5秒，出現:你，預測值:0.8687335848808289
# 1分50.75秒，出現:那那個，預測值:0.5731579065322876
# 1分51.0秒，出現:的這個，預測值:0.8119592666625977
# 1分51.25秒，出現:的這個，預測值:0.7980877757072449
# 1分52.0秒，出現:的這個，預測值:0.7355594635009766
# 1分52.25秒，出現:你，預測值:0.9891658425331116
# 1分52.5秒，出現:你，預測值:0.6682360768318176
# 1分52.75秒，出現:的那個，預測值:0.5611462593078613
# 1分53.0秒，出現:ㄏㄧㄡ，預測值:0.8760973811149597
# 1分53.25秒，出現:那那個，預測值:0.6152151226997375
# 1分53.5秒，出現:你，預測值:0.5898628234863281
# 1分53.75秒，出現:那那個，預測值:0.98478764295578
# 1分54.0秒，出現:那，預測值:0.5787776112556458
# 1分54.25秒，出現:你，預測值:0.9760221838951111
# 1分54.5秒，出現:你，預測值:0.9103729724884033
# 1分55.0秒，出現:你，預測值:0.8713293075561523
# 1分55.25秒，出現:你，預測值:0.921835720539093
# 1分55.5秒，出現:那那個，預測值:0.6510403156280518
# 1分55.75秒，出現:那那個，預測值:0.9872532486915588
# 1分56.25秒，出現:我，預測值:0.853233277797699
# 1分56.75秒，出現:那那個，預測值:0.8495445847511292
# 1分57.0秒，出現:的一個，預測值:0.8429181575775146
# 1分57.5秒，出現:的這個，預測值:0.7624006867408752
# 1分57.75秒，出現:那那個，預測值:0.7600500583648682
# 1分58.0秒，出現:我，預測值:0.9745292067527771
# 1分58.25秒，出現:的這個，預測值:0.7986235022544861
# 1分58.75秒，出現:的這個，預測值:0.9236988425254822
# 1分59.25秒，出現:你，預測值:0.96357661485672
# 1分59.5秒，出現:的一個，預測值:0.7962119579315186
# 1分59.75秒，出現:那那個，預測值:0.9765451550483704
# 2分0秒，出現:的這個，預測值:0.7910752892494202
# 2分0.25秒，出現:的這個，預測值:0.7054735422134399
# 2分0.5秒，出現:的一個，預測值:0.8573887944221497
# 2分1.0秒，出現:你，預測值:0.9974197149276733
# 2分1.5秒，出現:你，預測值:0.8170272707939148
# 2分2.0秒，出現:的一個，預測值:0.7993712425231934
# 2分2.5秒，出現:backgroundNoise，預測值:0.7861546874046326
# 2分3.0秒，出現:的一個，預測值:0.9990621209144592
# 2分3.25秒，出現:我，預測值:0.8312128186225891
# 2分3.75秒，出現:你，預測值:0.5418093800544739
# 2分4.0秒，出現:的一個，預測值:0.9322211742401123
# 2分4.25秒，出現:我，預測值:0.8422624468803406
# 2分4.5秒，出現:那那個，預測值:0.7394653558731079
# 2分4.75秒，出現:的一個，預測值:0.8792806267738342
# 2分5.0秒，出現:你，預測值:0.9186877608299255
# 2分5.5秒，出現:的這個，預測值:0.7370719909667969
# 2分5.75秒，出現:的一個，預測值:0.5474844574928284
# 2分6.0秒，出現:那那個，預測值:0.5111515522003174
# 2分6.25秒，出現:那那個，預測值:0.9689573645591736
# 2分6.75秒，出現:的一個，預測值:0.7770929336547852
# 2分7.0秒，出現:你，預測值:0.7028024792671204
# 2分7.25秒，出現:你，預測值:0.9845557808876038
# 2分7.5秒，出現:你，預測值:0.9973311424255371
# 2分8.0秒，出現:那那個，預測值:0.8917163014411926
# 2分8.25秒，出現:backgroundNoise，預測值:0.5076826810836792
# 2分8.5秒，出現:那，預測值:0.6669710278511047
# 2分8.75秒，出現:backgroundNoise，預測值:0.950002133846283
# 2分9.0秒，出現:那那個，預測值:0.9300185441970825
# 2分9.25秒，出現:那那個，預測值:0.8203594088554382
# 2分9.5秒，出現:阿，預測值:0.916504979133606
# 2分9.75秒，出現:我，預測值:0.6790690422058105
# 2分10.0秒，出現:的這個，預測值:0.9944827556610107
# 2分10.25秒，出現:你，預測值:0.9977796673774719
# 2分10.5秒，出現:的那個，預測值:0.6641879677772522
# 2分10.75秒，出現:的這個，預測值:0.9661104083061218
# 2分11.0秒，出現:的這個，預測值:0.6672459244728088
# 2分11.25秒，出現:你，預測值:0.6090577244758606
# 2分11.5秒，出現:ㄟ，預測值:0.6783487796783447
# 2分11.75秒，出現:那那個，預測值:0.956913948059082
# 2分12.0秒，出現:那那個，預測值:0.9379618167877197
# 2分12.25秒，出現:你，預測值:0.9355495572090149
# 2分12.5秒，出現:我，預測值:0.8670904040336609
# 2分14.0秒，出現:我，預測值:0.5439347624778748
# 2分14.25秒，出現:阿，預測值:0.6327812075614929
# 2分14.5秒，出現:你，預測值:0.6138916611671448
# 2分14.75秒，出現:我，預測值:0.5268080234527588
# 2分15.0秒，出現:那那個，預測值:0.9800332188606262
# 2分15.25秒，出現:的一個，預測值:0.9019070863723755
# 2分15.5秒，出現:的這個，預測值:0.99125075340271
# 2分15.75秒，出現:那那個，預測值:0.6308169364929199
# 2分16.25秒，出現:那那個，預測值:0.5074916481971741
# 2分16.5秒，出現:ㄟ，預測值:0.8187564015388489
# 2分17.5秒，出現:的一個，預測值:0.869234025478363
# 2分18.25秒，出現:那那個，預測值:0.8146026134490967
# 2分18.5秒，出現:那那個，預測值:0.9768126010894775
# 2分18.75秒，出現:的一個，預測值:0.6292809844017029
# 2分19.0秒，出現:的這個，預測值:0.7654740214347839
# 2分19.25秒，出現:ㄏㄧㄡ，預測值:0.6467336416244507
# 2分19.75秒，出現:那那個，預測值:0.7182397842407227
# 2分20.0秒，出現:那那個，預測值:0.6547757387161255
# 2分20.25秒，出現:你，預測值:0.917261004447937
# 2分20.75秒，出現:你，預測值:0.994246780872345
# 2分21.0秒，出現:那，預測值:0.8262466788291931
# 2分21.25秒，出現:的那個，預測值:0.5816558599472046
# 2分21.5秒，出現:你，預測值:0.682746410369873
# 2分21.75秒，出現:的一個，預測值:0.6121630668640137
# 2分22.0秒，出現:那那個，預測值:0.7886669635772705
# 2分22.5秒，出現:的一個，預測值:0.9622894525527954
# 2分23.0秒，出現:的這個，預測值:0.5813488960266113
# 2分23.25秒，出現:那那個，預測值:0.9399983286857605
# 2分23.5秒，出現:的一個，預測值:0.907991349697113
# 2分23.75秒，出現:那那個，預測值:0.9457613229751587
# 2分24.0秒，出現:你，預測值:0.7629966735839844
# 2分24.25秒，出現:你，預測值:0.9748443961143494
# 2分24.5秒，出現:你，預測值:0.9728887677192688
# 2分24.75秒，出現:的一個，預測值:0.5936605930328369
# 2分25.0秒，出現:那那個，預測值:0.5283353328704834
# 2分25.25秒，出現:的這個，預測值:0.5689781904220581
# 2分25.5秒，出現:你，預測值:0.9897235631942749
# 2分25.75秒，出現:那，預測值:0.9991171956062317
# 2分26.5秒，出現:那那個，預測值:0.9216552972793579
# 2分26.75秒，出現:的那個，預測值:0.6799996495246887
# 2分27.0秒，出現:的這個，預測值:0.8075894713401794
# 2分27.25秒，出現:的這個，預測值:0.5413132905960083
# 2分27.5秒，出現:我，預測值:0.9617113471031189
# 2分27.75秒，出現:的這個，預測值:0.9371963143348694
# 2分28.0秒，出現:你，預測值:0.93989098072052
# 2分28.25秒，出現:的這個，預測值:0.6188367009162903
# 2分28.5秒，出現:的這個，預測值:0.9685216546058655
# 2分29.25秒，出現:那那個，預測值:0.5051576495170593
# 2分29.5秒，出現:的這個，預測值:0.783955454826355
# 2分29.75秒，出現:我，預測值:0.5175561308860779
# 2分30.0秒，出現:的這個，預測值:0.8339219689369202
# 2分30.25秒，出現:你，預測值:0.9837633371353149
# 2分30.5秒，出現:backgroundNoise，預測值:0.9276823997497559
# 2分30.75秒，出現:你，預測值:0.8393731713294983
# 2分31.0秒，出現:那，預測值:0.9659696817398071
# 2分31.25秒，出現:你，預測值:0.5915046334266663
# 2分31.5秒，出現:的這個，預測值:0.6722211837768555
# 2分31.75秒，出現:你，預測值:0.9477323889732361
# 2分32.0秒，出現:那那個，預測值:0.8077027797698975
# 2分32.25秒，出現:你，預測值:0.6708722710609436
# 2分32.5秒，出現:我，預測值:0.9905132055282593
# 2分32.75秒，出現:那那個，預測值:0.6642893552780151
# 2分33.0秒，出現:那那個，預測值:0.9402891397476196
# 2分33.25秒，出現:的這個，預測值:0.6949006915092468
# 2分33.5秒，出現:的這個，預測值:0.765262246131897
# 2分33.75秒，出現:你，預測值:0.864494264125824
# 2分34.0秒，出現:你，預測值:0.9912334084510803
# 2分34.25秒，出現:我，預測值:0.9956385493278503
# 2分34.75秒，出現:你，預測值:0.9853923916816711
# 2分35.0秒，出現:你，預測值:0.8706405758857727
# 2分35.25秒，出現:ㄟ，預測值:0.8272198438644409
# 2分35.5秒，出現:的這個，預測值:0.7477993965148926
# 2分36.25秒，出現:那那個，預測值:0.6032135486602783
# 2分36.5秒，出現:你，預測值:0.5245139598846436
# 2分37.0秒，出現:你，預測值:0.9995369911193848
# 2分37.25秒，出現:你，預測值:0.9953334927558899
# 2分37.5秒，出現:你，預測值:0.9813485741615295
# 2分37.75秒，出現:那，預測值:0.9165554642677307
# 2分38.0秒，出現:那那個，預測值:0.9273145794868469
# 2分38.25秒，出現:的這個，預測值:0.9015750885009766
# 2分38.5秒，出現:的一個，預測值:0.5446277856826782
# 2分38.75秒，出現:的一個，預測值:0.6265048384666443
# 2分39.0秒，出現:嗯，預測值:0.8243987560272217
# 2分39.25秒，出現:你，預測值:0.7504897117614746
# 2分39.5秒，出現:那那個，預測值:0.5809555649757385
# 2分39.75秒，出現:那那個，預測值:0.7501869201660156
# 2分40.25秒，出現:你，預測值:0.5640835165977478
# 2分40.5秒，出現:的一個，預測值:0.6904473304748535
# 2分40.75秒，出現:你，預測值:0.6232452392578125
# 2分41.0秒，出現:我，預測值:0.8179534077644348
# 2分41.25秒，出現:阿，預測值:0.734509289264679
# 2分41.75秒，出現:那那個，預測值:0.6255826354026794
# 2分42.0秒，出現:你，預測值:0.6903200745582581
# 2分42.25秒，出現:你，預測值:0.5644903182983398
# 2分42.75秒，出現:那那個，預測值:0.9641505479812622
# 2分43.0秒，出現:那那個，預測值:0.9560506343841553
# 2分43.25秒，出現:你，預測值:0.9997262358665466
# 2分43.5秒，出現:你，預測值:0.8063941597938538
# 2分43.75秒，出現:那那個，預測值:0.9212774634361267
# 2分44.0秒，出現:那那個，預測值:0.7114480137825012
# 2分44.25秒，出現:的一個，預測值:0.9476780295372009
# 2分44.5秒，出現:的一個，預測值:0.6494264006614685
# 2分44.75秒，出現:你，預測值:0.9931731820106506
# 2分45.0秒，出現:的一個，預測值:0.9633435606956482
# 2分45.25秒，出現:的那個，預測值:0.5912343263626099
# 2分45.5秒，出現:你，預測值:0.9981427192687988
# 2分46.0秒，出現:的那個，預測值:0.9467993378639221
# 2分46.75秒，出現:的一個，預測值:0.7077419757843018
# 2分47.25秒，出現:的那個，預測值:0.620297372341156
# 2分47.75秒，出現:的一個，預測值:0.9735342860221863
# 2分48.0秒，出現:那那個，預測值:0.6813732385635376
# 2分48.5秒，出現:那那個，預測值:0.7686019539833069
# 2分48.75秒，出現:的這個，預測值:0.9480032920837402
# 2分49.0秒，出現:你，預測值:0.9991920590400696
# 2分49.25秒，出現:那那個，預測值:0.8987023234367371
# 2分49.5秒，出現:你，預測值:0.9658452868461609
# 2分49.75秒，出現:你，預測值:0.9963868856430054
# 2分50.0秒，出現:你，預測值:0.6257416009902954
# 2分50.25秒，出現:你，預測值:0.9985048770904541
# 2分50.5秒，出現:的一個，預測值:0.5502273440361023
# 2分50.75秒，出現:的這個，預測值:0.9403809309005737
# 2分51.25秒，出現:的一個，預測值:0.8743879795074463
# 2分51.5秒，出現:你，預測值:0.5703322291374207
# 2分51.75秒，出現:那那個，預測值:0.957127034664154
# 2分52.0秒，出現:那那個，預測值:0.9073988199234009
# 2分52.25秒，出現:的一個，預測值:0.8232425451278687
# 2分52.5秒，出現:的這個，預測值:0.7072877883911133
# 2分52.75秒，出現:你，預測值:0.7428184151649475
# 2分53.0秒，出現:你，預測值:0.8481876254081726
# 2分53.25秒，出現:你，預測值:0.9601215720176697
# 2分54.25秒，出現:那那個，預測值:0.7949894666671753
# 2分54.5秒，出現:啦，預測值:0.9127495288848877
# 2分55.25秒，出現:backgroundNoise，預測值:0.5551232099533081
# 2分55.5秒，出現:的這個，預測值:0.996515154838562
# 2分55.75秒，出現:那那個，預測值:0.6334539651870728
# 2分56.75秒，出現:你，預測值:0.6833594441413879
# 2分57.0秒，出現:那那個，預測值:0.7885464429855347
# 2分57.25秒，出現:backgroundNoise，預測值:0.8531630635261536
# 2分58.75秒，出現:backgroundNoise，預測值:0.7734369039535522
