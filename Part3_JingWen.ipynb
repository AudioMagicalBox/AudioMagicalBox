# %%
"""將tensorflow檔轉成tensorflow lite，使機器負載量變小"""
from tensorflow import lite
from tensorflow.keras import models

# Parameters
keras_model_filename = './h5/recording23.h5' #訓練好的模型
tflite_filename = './tflite/recording23.tflite' #預建置檔案

# Convert model to TF Lite model
model = models.load_model(keras_model_filename) #載入本來的模型
converter = lite.TFLiteConverter.from_keras_model(model) #將模型載入轉換器
tflite_model = converter.convert() #進行轉換
open(tflite_filename, 'wb').write(tflite_model) #輸出轉換後的模型
# Out:
# INFO:tensorflow:Assets written to: C:\Users\user\AppData\Local\Temp\tmp8kyshiym\assets
# 285876

# %%
import openpyxl
import pandas as pd
import sounddevice as sd
import numpy as np
import scipy.signal
import python_speech_features
import tensorflow as tf
from PyQt5.QtCore import QTime
import librosa

num_mfcc = 23 #回傳mfcc的量

model_path = './tflite/recording23.tflite'
words = ['ㄏㄧㄡ', 'ㄟ', '吼', '啦', '嗯', '的一個', '的這個', '的那個', '著', '那', '那那個', '阿']#答案對應到的字詞
data = []
start = 0 #開始的索引值
end = 4000 #結束的索引值
s = 0.5 #sec
m = 0 #min
duration = 180 #讀取音檔時間的總和 (3分鐘)
sample_rate = 8000 #取樣率

#載入音檔
f_name = 'C:/Users/user/Desktop/testREC.wav'
y,sr= librosa.load(f_name,sr=sample_rate,duration=duration)
t = y.size / float(sr)
print("y =>",y)
print("y_len =",len(y))
print("Time =",t,"sec\n")

# Sliding window
window = np.zeros(8000)#取樣音頻數據變數

# Load model (interpreter)
interpreter = tf.lite.Interpreter(model_path)
interpreter.allocate_tensors()
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# This gets called every 0.5 seconds
def sound_file(window,s,m):
    S = np.abs(librosa.stft(window)) #將整個window音訊做stft，並轉成絕對值
    #print("np.sum(S):" + str(np.sum(S)))
    
    if np.sum(S) > 3000: #判斷是否有講話
        # Compute features
        mfccs = python_speech_features.base.mfcc(window, #輸入訊號
                                            samplerate=8000, #取樣率
                                            winlen=0.256, #音框涵蓋時間
                                            winstep=0.050, #音框間距離
                                            numcep=num_mfcc, #返回係數的量
                                            nfilt=26, #過濾器數量
                                            nfft=2048,#FFT大小
                                            preemph=0.0,#不用預強化濾波器
                                            ceplifter=0,#ROBUST
                                            appendEnergy=True,#係數0的話對被替代成總音框能量的對數
                                            winfunc=np.hanning)#hanning window
        mfccs = mfccs.transpose()
        
        # Make prediction from model
        in_tensor = np.float32(mfccs.reshape(1, mfccs.shape[0], mfccs.shape[1], 1))
        #設定輸入張量
        interpreter.set_tensor(input_details[0]['index'], in_tensor)
        #進行預測
        interpreter.invoke()
        #取得輸出張量
        output_data = interpreter.get_tensor(output_details[0]['index'])
        
        val = output_data[0]#取得預測值
        val = val.tolist() #np.ndarray to list
        list_val_max = max(val) #取得最大值
        list_val_maxIndex = val.index(max(val)) #取得最大值的索引  
        
        #if list_val_maxIndex == 0:
            
        if(list_val_maxIndex>=0 and list_val_max >= 0.5):
            data.append(str(m) + "分" + "{:.1f}秒".format(s) + "  出現：" + str(words[list_val_maxIndex]) 
                        + "  預測值：{:.3f}".format(list_val_max)+"\n")             
            
while True:
    window[0:4000] = y[start:end] #把音訊載入window
    start = start + 4000 #向後移動
    end = end + 4000 #向後移動
    window[4000:] = y[start:end] #把音訊載入window
    s = float(s + 0.5) #增加秒數
    if(s == 60): #60 sec <-> 1 min
        s = 0
        m = m + 1
    sound_file(window,s,m) #呼叫sound_file()
    if(end == 1440000): #如果移動到最後break       
        break

for i in range(len(data)):
        print(data[i])
        
print("總共預測：",len(data),"個")

s1 = pd.Series(data)
s1.to_excel('RecData.xlsx')
fn = 'RecData.xlsx'
wb = openpyxl.load_workbook(fn)
ws = wb.active
ws.move_range("B2:G500", rows=-1, cols=-1)
wb.save(fn)
# Out:
# y => [ 5.1879883e-04  3.9672852e-04  2.1362305e-04 ... -7.3852539e-03
#  -5.0048828e-03 -3.0517578e-05]
# y_len = 1440000
# Time = 180.0 sec
#
# 0分3.5秒  出現：嗯  預測值：0.628
#
# 0分4.0秒  出現：嗯  預測值：0.950
#
# 0分4.5秒  出現：的一個  預測值：0.692
#
# 0分5.0秒  出現：的一個  預測值：1.000
#
# 0分5.5秒  出現：的一個  預測值：1.000
#
# 0分6.0秒  出現：嗯  預測值：0.756
#
# 0分7.0秒  出現：嗯  預測值：0.931
#
# 0分7.5秒  出現：的一個  預測值：0.712
#
# 0分8.0秒  出現：嗯  預測值：1.000
#
# 0分8.5秒  出現：嗯  預測值：0.957
#
# 0分9.0秒  出現：的一個  預測值：0.986
#
# 0分9.5秒  出現：嗯  預測值：0.984
#
# 0分10.5秒  出現：的一個  預測值：1.000
#
# 0分11.0秒  出現：的一個  預測值：0.999
#
# 0分11.5秒  出現：嗯  預測值：0.932
#
# 0分12.0秒  出現：的一個  預測值：0.845
#
# 0分12.5秒  出現：的一個  預測值：1.000
#
# 0分13.0秒  出現：的一個  預測值：1.000
#
# 0分13.5秒  出現：嗯  預測值：0.999
#
# 0分14.0秒  出現：嗯  預測值：0.884
#
# 0分14.5秒  出現：的一個  預測值：0.995
#
# 0分15.0秒  出現：的一個  預測值：0.537
#
# 0分15.5秒  出現：的一個  預測值：0.974
#
# 0分16.0秒  出現：嗯  預測值：0.980
#
# 0分16.5秒  出現：的一個  預測值：0.913
#
# 0分17.0秒  出現：的一個  預測值：0.996
#
# 0分17.5秒  出現：嗯  預測值：0.910
#
# 0分18.0秒  出現：嗯  預測值：0.701
#
# 0分18.5秒  出現：的一個  預測值：0.967
#
# 0分19.0秒  出現：的一個  預測值：1.000
#
# 0分20.5秒  出現：嗯  預測值：0.999
#
# 0分21.0秒  出現：的一個  預測值：1.000
#
# 0分21.5秒  出現：的一個  預測值：0.608
#
# 0分22.0秒  出現：的一個  預測值：0.999
#
# 0分22.5秒  出現：的一個  預測值：0.974
#
# 0分23.0秒  出現：的一個  預測值：0.999
#
# 0分23.5秒  出現：的一個  預測值：0.995
#
# 0分24.0秒  出現：的一個  預測值：1.000
#
# 0分24.5秒  出現：那  預測值：0.904
#
# 0分25.0秒  出現：嗯  預測值：0.762
#
# 0分25.5秒  出現：的一個  預測值：0.585
#
# 0分26.0秒  出現：的一個  預測值：0.983
#
# 0分26.5秒  出現：嗯  預測值：0.716
#
# 0分27.0秒  出現：嗯  預測值：0.958
#
# 0分27.5秒  出現：的一個  預測值：0.904
#
# 0分28.0秒  出現：的一個  預測值：1.000
#
# 0分28.5秒  出現：嗯  預測值：0.510
#
# 0分29.0秒  出現：嗯  預測值：0.862
#
# 0分29.5秒  出現：的一個  預測值：0.999
#
# 0分30.0秒  出現：的一個  預測值：0.999
#
# 0分30.5秒  出現：的一個  預測值：0.994
#
# 0分31.0秒  出現：嗯  預測值：0.995
#
# 0分31.5秒  出現：的一個  預測值：1.000
#
# 0分32.0秒  出現：嗯  預測值：0.716
#
# 0分32.5秒  出現：的一個  預測值：0.977
#
# 0分33.0秒  出現：的一個  預測值：0.991
#
# 0分33.5秒  出現：嗯  預測值：0.909
#
# 0分34.0秒  出現：的一個  預測值：0.957
#
# 0分34.5秒  出現：的一個  預測值：0.963
#
# 0分35.0秒  出現：嗯  預測值：0.542
#
# 0分36.0秒  出現：的一個  預測值：1.000
#
# 0分37.0秒  出現：嗯  預測值：0.999
#
# 0分37.5秒  出現：的一個  預測值：0.967
#
# 0分38.0秒  出現：嗯  預測值：0.714
#
# 0分38.5秒  出現：的一個  預測值：0.999
#
# 0分39.0秒  出現：嗯  預測值：0.634
#
# 0分39.5秒  出現：的一個  預測值：0.999
#
# 0分40.0秒  出現：的一個  預測值：1.000
#
# 0分40.5秒  出現：的一個  預測值：1.000
#
# 0分41.0秒  出現：的一個  預測值：0.999
#
# 0分41.5秒  出現：嗯  預測值：0.992
#
# 0分42.5秒  出現：的一個  預測值：1.000
#
# 0分43.0秒  出現：嗯  預測值：0.993
#
# 0分43.5秒  出現：嗯  預測值：0.995
#
# 0分44.0秒  出現：的一個  預測值：0.930
#
# 0分44.5秒  出現：的一個  預測值：0.998
#
# 0分45.0秒  出現：嗯  預測值：1.000
#
# 0分45.5秒  出現：嗯  預測值：0.999
#
# 0分46.0秒  出現：的一個  預測值：0.989
#
# 0分46.5秒  出現：嗯  預測值：0.998
#
# 0分47.0秒  出現：的一個  預測值：0.998
#
# 0分47.5秒  出現：的一個  預測值：0.966
#
# 0分48.0秒  出現：的一個  預測值：0.998
#
# 0分48.5秒  出現：的一個  預測值：0.967
#
# 0分49.0秒  出現：嗯  預測值：0.997
#
# 0分49.5秒  出現：的一個  預測值：0.992
#
# 0分50.0秒  出現：的一個  預測值：0.998
#
# 0分50.5秒  出現：嗯  預測值：0.763
#
# 0分51.0秒  出現：的一個  預測值：0.995
#
# 0分51.5秒  出現：的一個  預測值：0.991
#
# 0分52.0秒  出現：的一個  預測值：0.999
#
# 0分52.5秒  出現：的一個  預測值：0.911
#
# 0分53.5秒  出現：嗯  預測值：0.931
#
# 0分54.0秒  出現：嗯  預測值：0.986
#
# 0分54.5秒  出現：嗯  預測值：0.876
#
# 0分55.0秒  出現：的一個  預測值：0.991
#
# 0分55.5秒  出現：的一個  預測值：1.000
#
# 0分56.0秒  出現：嗯  預測值：0.767
#
# 0分56.5秒  出現：的一個  預測值：0.866
#
# 1分1.0秒  出現：嗯  預測值：1.000
#
# 1分1.5秒  出現：嗯  預測值：1.000
#
# 1分2.0秒  出現：嗯  預測值：0.500
#
# 1分2.5秒  出現：的一個  預測值：0.945
#
# 1分3.0秒  出現：的一個  預測值：0.609
#
# 1分3.5秒  出現：嗯  預測值：0.901
#
# 1分4.0秒  出現：的一個  預測值：0.984
#
# 1分4.5秒  出現：嗯  預測值：0.993
#
# 1分5.0秒  出現：嗯  預測值：0.871
#
# 1分5.5秒  出現：著  預測值：0.529
#
# 1分6.0秒  出現：嗯  預測值：0.984
#
# 1分6.5秒  出現：的一個  預測值：0.945
#
# 1分7.0秒  出現：嗯  預測值：0.734
#
# 1分7.5秒  出現：的一個  預測值：0.987
#
# 1分8.0秒  出現：的一個  預測值：0.992
#
# 1分8.5秒  出現：的一個  預測值：1.000
#
# 1分9.0秒  出現：的一個  預測值：0.998
#
# 1分9.5秒  出現：的一個  預測值：0.999
#
# 1分10.0秒  出現：的一個  預測值：0.997
#
# 1分10.5秒  出現：嗯  預測值：1.000
#
# 1分11.0秒  出現：嗯  預測值：0.999
#
# 1分11.5秒  出現：的一個  預測值：1.000
#
# 1分12.0秒  出現：的一個  預測值：1.000
#
# 1分12.5秒  出現：的一個  預測值：0.995
#
# 1分13.0秒  出現：嗯  預測值：0.801
#
# 1分13.5秒  出現：的一個  預測值：0.998
#
# 1分14.0秒  出現：的一個  預測值：0.617
#
# 1分14.5秒  出現：的一個  預測值：0.994
#
# 1分15.0秒  出現：的一個  預測值：0.877
#
# 1分15.5秒  出現：嗯  預測值：0.996
#
# 1分16.0秒  出現：的一個  預測值：1.000
#
# 1分16.5秒  出現：的一個  預測值：0.993
#
# 1分17.0秒  出現：的一個  預測值：0.997
#
# 1分21.5秒  出現：嗯  預測值：0.999
#
# 1分22.0秒  出現：嗯  預測值：0.999
#
# 1分22.5秒  出現：嗯  預測值：0.912
#
# 1分23.0秒  出現：的一個  預測值：0.821
#
# 1分23.5秒  出現：的一個  預測值：0.527
#
# 1分24.0秒  出現：嗯  預測值：0.993
#
# 1分24.5秒  出現：的一個  預測值：0.967
#
# 1分25.0秒  出現：的一個  預測值：1.000
#
# 1分25.5秒  出現：那  預測值：0.625
#
# 1分26.0秒  出現：嗯  預測值：0.913
#
# 1分26.5秒  出現：的一個  預測值：0.987
#
# 1分27.0秒  出現：的一個  預測值：1.000
#
# 1分27.5秒  出現：嗯  預測值：0.824
#
# 1分28.0秒  出現：的一個  預測值：0.607
#
# 1分28.5秒  出現：嗯  預測值：0.998
#
# 1分29.0秒  出現：的一個  預測值：0.740
#
# 1分30.0秒  出現：的一個  預測值：1.000
#
# 1分30.5秒  出現：嗯  預測值：0.952
#
# 1分31.0秒  出現：的一個  預測值：1.000
#
# 1分31.5秒  出現：嗯  預測值：0.737
#
# 1分32.0秒  出現：的一個  預測值：0.807
#
# 1分33.0秒  出現：嗯  預測值：0.918
#
# 1分33.5秒  出現：的一個  預測值：0.940
#
# 1分34.0秒  出現：的一個  預測值：1.000
#
# 1分34.5秒  出現：嗯  預測值：0.991
#
# 1分35.0秒  出現：的一個  預測值：0.923
#
# 1分35.5秒  出現：的一個  預測值：0.820
#
# 1分36.0秒  出現：的一個  預測值：0.839
#
# 1分36.5秒  出現：的一個  預測值：0.998
#
# 1分37.0秒  出現：的一個  預測值：1.000
#
# 1分37.5秒  出現：的一個  預測值：0.997
#
# 1分38.0秒  出現：的一個  預測值：0.989
#
# 1分38.5秒  出現：的一個  預測值：1.000
#
# 1分39.0秒  出現：嗯  預測值：1.000
#
# 1分39.5秒  出現：嗯  預測值：0.658
#
# 1分40.0秒  出現：的一個  預測值：0.996
#
# 1分40.5秒  出現：的一個  預測值：1.000
#
# 1分41.0秒  出現：嗯  預測值：0.921
#
# 1分41.5秒  出現：的一個  預測值：0.997
#
# 1分42.0秒  出現：的一個  預測值：0.757
#
# 1分42.5秒  出現：的一個  預測值：0.781
#
# 1分43.0秒  出現：的一個  預測值：0.828
#
# 1分43.5秒  出現：的一個  預測值：0.809
#
# 1分44.0秒  出現：嗯  預測值：0.995
#
# 1分44.5秒  出現：的一個  預測值：0.999
#
# 1分45.0秒  出現：的一個  預測值：1.000
#
# 1分45.5秒  出現：嗯  預測值：0.615
#
# 1分46.0秒  出現：的一個  預測值：0.950
#
# 1分46.5秒  出現：的一個  預測值：0.953
#
# 1分47.0秒  出現：的一個  預測值：1.000
#
# 1分48.0秒  出現：嗯  預測值：0.994
#
# 1分48.5秒  出現：的一個  預測值：0.999
#
# 1分49.0秒  出現：嗯  預測值：0.998
#
# 1分49.5秒  出現：的一個  預測值：0.990
#
# 1分50.0秒  出現：著  預測值：0.652
#
# 1分50.5秒  出現：嗯  預測值：0.945
#
# 1分51.0秒  出現：的一個  預測值：1.000
#
# 1分51.5秒  出現：嗯  預測值：0.919
#
# 1分52.0秒  出現：的一個  預測值：0.998
#
# 1分52.5秒  出現：嗯  預測值：0.957
#
# 1分53.0秒  出現：的一個  預測值：0.987
#
# 1分53.5秒  出現：的一個  預測值：1.000
#
# 1分54.0秒  出現：的一個  預測值：0.978
#
# 1分54.5秒  出現：嗯  預測值：0.670
#
# 1分55.0秒  出現：嗯  預測值：0.999
#
# 1分55.5秒  出現：嗯  預測值：0.698
#
# 1分56.0秒  出現：的一個  預測值：0.783
#
# 1分56.5秒  出現：的一個  預測值：0.999
#
# 1分57.0秒  出現：的一個  預測值：0.829
#
# 1分57.5秒  出現：的一個  預測值：0.957
#
# 1分58.0秒  出現：的一個  預測值：0.502
#
# 1分58.5秒  出現：的一個  預測值：0.966
#
# 1分59.0秒  出現：嗯  預測值：0.715
#
# 1分59.5秒  出現：的一個  預測值：0.938
#
# 2分0.0秒  出現：的一個  預測值：0.998
#
# 2分0.5秒  出現：的一個  預測值：0.621
#
# 2分1.0秒  出現：的一個  預測值：0.975
#
# 2分1.5秒  出現：嗯  預測值：0.931
#
# 2分2.0秒  出現：嗯  預測值：0.933
#
# 2分2.5秒  出現：嗯  預測值：0.690
#
# 2分3.0秒  出現：嗯  預測值：0.673
#
# 2分3.5秒  出現：吼  預測值：0.733
#
# 2分4.0秒  出現：嗯  預測值：0.963
#
# 2分4.5秒  出現：嗯  預測值：0.978
#
# 2分5.0秒  出現：嗯  預測值：0.623
#
# 2分5.5秒  出現：的一個  預測值：1.000
#
# 2分6.0秒  出現：嗯  預測值：0.984
#
# 2分6.5秒  出現：嗯  預測值：0.738
#
# 2分7.0秒  出現：嗯  預測值：0.946
#
# 2分7.5秒  出現：嗯  預測值：0.608
#
# 2分8.0秒  出現：嗯  預測值：0.985
#
# 2分8.5秒  出現：的一個  預測值：0.997
#
# 2分9.0秒  出現：的一個  預測值：1.000
#
# 2分10.0秒  出現：的一個  預測值：1.000
#
# 2分10.5秒  出現：的一個  預測值：1.000
#
# 2分11.5秒  出現：嗯  預測值：0.999
#
# 2分12.0秒  出現：的一個  預測值：0.595
#
# 2分12.5秒  出現：的一個  預測值：1.000
#
# 2分13.0秒  出現：的一個  預測值：1.000
#
# 2分13.5秒  出現：的一個  預測值：0.996
#
# 2分14.0秒  出現：嗯  預測值：0.644
#
# 2分14.5秒  出現：的一個  預測值：0.992
#
# 2分15.0秒  出現：的一個  預測值：0.995
#
# 2分15.5秒  出現：的一個  預測值：0.746
#
# 2分16.0秒  出現：嗯  預測值：0.996
#
# 2分16.5秒  出現：的一個  預測值：0.725
#
# 2分17.0秒  出現：的一個  預測值：0.944
#
# 2分17.5秒  出現：的一個  預測值：0.871
#
# 2分18.0秒  出現：嗯  預測值：0.514
#
# 2分18.5秒  出現：的一個  預測值：0.947
#
# 2分19.0秒  出現：嗯  預測值：0.987
#
# 2分19.5秒  出現：的一個  預測值：1.000
#
# 2分20.0秒  出現：的一個  預測值：0.754
#
# 2分20.5秒  出現：的一個  預測值：0.999
#
# 2分21.0秒  出現：的一個  預測值：0.580
#
# 2分21.5秒  出現：嗯  預測值：1.000
#
# 2分22.0秒  出現：嗯  預測值：0.821
#
# 2分22.5秒  出現：的一個  預測值：0.978
#
# 2分23.0秒  出現：的一個  預測值：0.926
#
# 2分23.5秒  出現：的一個  預測值：0.993
#
# 2分24.0秒  出現：的一個  預測值：0.955
#
# 2分24.5秒  出現：的一個  預測值：0.928
#
# 2分25.0秒  出現：嗯  預測值：0.969
#
# 2分25.5秒  出現：的一個  預測值：0.938
#
# 2分26.0秒  出現：嗯  預測值：0.996
#
# 2分26.5秒  出現：的一個  預測值：0.986
#
# 2分27.5秒  出現：嗯  預測值：0.998
#
# 2分28.0秒  出現：嗯  預測值：0.885
#
# 2分28.5秒  出現：的一個  預測值：0.977
#
# 2分29.0秒  出現：的一個  預測值：1.000
#
# 2分29.5秒  出現：的一個  預測值：0.894
#
# 2分30.0秒  出現：嗯  預測值：1.000
#
# 2分30.5秒  出現：嗯  預測值：0.992
#
# 2分31.0秒  出現：嗯  預測值：0.908
#
# 2分31.5秒  出現：嗯  預測值：0.848
#
# 2分32.0秒  出現：的一個  預測值：0.921
#
# 2分32.5秒  出現：嗯  預測值：0.729
#
# 2分33.0秒  出現：的一個  預測值：1.000
#
# 2分33.5秒  出現：的一個  預測值：1.000
#
# 2分34.0秒  出現：嗯  預測值：0.999
#
# 2分34.5秒  出現：嗯  預測值：0.989
#
# 2分35.0秒  出現：的一個  預測值：0.937
#
# 2分35.5秒  出現：嗯  預測值：0.507
#
# 2分36.0秒  出現：嗯  預測值：0.975
#
# 2分36.5秒  出現：的一個  預測值：0.976
#
# 2分37.0秒  出現：的一個  預測值：0.951
#
# 2分37.5秒  出現：嗯  預測值：0.613
#
# 2分38.0秒  出現：嗯  預測值：0.761
#
# 2分39.0秒  出現：嗯  預測值：0.997
#
# 2分39.5秒  出現：嗯  預測值：0.972
#
# 2分40.0秒  出現：的一個  預測值：0.997
#
# 2分40.5秒  出現：嗯  預測值：0.976
#
# 2分41.0秒  出現：的一個  預測值：0.765
#
# 2分41.5秒  出現：的一個  預測值：0.978
#
# 2分42.0秒  出現：嗯  預測值：0.938
#
# 2分42.5秒  出現：的一個  預測值：0.845
#
# 2分43.0秒  出現：的一個  預測值：0.662
#
# 2分43.5秒  出現：嗯  預測值：0.999
#
# 2分44.0秒  出現：嗯  預測值：0.612
#
# 2分44.5秒  出現：嗯  預測值：0.613
#
# 2分45.0秒  出現：嗯  預測值：0.565
#
# 2分45.5秒  出現：嗯  預測值：0.991
#
# 2分46.0秒  出現：的一個  預測值：1.000
#
# 2分46.5秒  出現：嗯  預測值：0.957
#
# 2分47.0秒  出現：的一個  預測值：0.980
#
# 2分47.5秒  出現：的一個  預測值：1.000
#
# 2分48.0秒  出現：的一個  預測值：1.000
#
# 2分49.0秒  出現：嗯  預測值：0.999
#
# 2分49.5秒  出現：嗯  預測值：0.976
#
# 2分50.0秒  出現：嗯  預測值：0.999
#
# 2分50.5秒  出現：的一個  預測值：0.933
#
# 2分51.0秒  出現：的一個  預測值：0.997
#
# 2分51.5秒  出現：嗯  預測值：0.882
#
# 2分52.0秒  出現：嗯  預測值：1.000
#
# 2分52.5秒  出現：嗯  預測值：1.000
#
# 2分53.0秒  出現：的一個  預測值：0.799
#
# 2分53.5秒  出現：嗯  預測值：0.998
#
# 2分54.0秒  出現：的一個  預測值：0.900
#
# 2分54.5秒  出現：嗯  預測值：1.000
#
# 2分55.0秒  出現：嗯  預測值：0.999
#
# 2分55.5秒  出現：嗯  預測值：0.953
#
# 2分56.0秒  出現：嗯  預測值：0.705
#
# 2分56.5秒  出現：的一個  預測值：0.999
#
# 2分58.5秒  出現：嗯  預測值：1.000
#
# 2分59.0秒  出現：的一個  預測值：0.824
#
# 2分59.5秒  出現：的一個  預測值：0.984
#
# 總共預測： 318 個
