# %%
"""將tensorflow檔轉成tensorflow lite，使機器負載量變小"""
from tensorflow import lite
from tensorflow.keras import models

# Parameters
keras_model_filename = './h5/appendEnergyTT_wen.h5' #訓練好的模型
tflite_filename = './tflite/appendEnergyTT_wen.tflite' #預建置檔案

# Convert model to TF Lite model
model = models.load_model(keras_model_filename) #載入本來的模型
converter = lite.TFLiteConverter.from_keras_model(model) #將模型載入轉換器
tflite_model = converter.convert() #進行轉換
open(tflite_filename, 'wb').write(tflite_model) #輸出轉換後的模型
# Out:
# INFO:tensorflow:Assets written to: C:\Users\user\AppData\Local\Temp\tmp4qdwm0uf\assets
# INFO:tensorflow:Assets written to: C:\Users\user\AppData\Local\Temp\tmp4qdwm0uf\assets
# 235300

# %%
#slide_window=0.25
import sounddevice as sd
import numpy as np
import scipy.signal
import python_speech_features
import tensorflow as tf
from PyQt5.QtCore import QTime
import librosa

# This gets called every 0.5 seconds
def sound(window,s,m):
    
    S = np.abs(librosa.stft(window)) #將整個window音訊做stft，並轉成絕對值
    
    if np.sum(S) > 3000: #判斷S的總和是否>3000，如果>3000，代表有講話
        # Compute features
        mfccs = python_speech_features.base.mfcc(window, #輸入訊號
                                            samplerate=8000, #取樣率
                                            winlen=0.256, #音框涵蓋時間
                                            winstep=0.050, #音框間距離
                                            numcep=num_mfcc, #返回係數的量
                                            nfilt=26, #過濾器數量
                                            nfft=2048,#FFT大小
                                            preemph=0.0,#不用預強化濾波器
                                            ceplifter=0,#ROBUST
                                            appendEnergy=True,#True的話，第0個倒頻譜係數被替代成總音框能量的對數
                                            winfunc=np.hanning)#hanning window
        mfccs = mfccs.transpose()
        
        # Make prediction from model
        in_tensor = np.float32(mfccs.reshape(1, mfccs.shape[0], mfccs.shape[1], 1))
        #設定輸入張量
        interpreter.set_tensor(input_details[0]['index'], in_tensor)
        #進行預測
        interpreter.invoke()
        #取得輸出張量
        output_data = interpreter.get_tensor(output_details[0]['index'])
        
        val = output_data[0]#取得預測值
        val = val.tolist() #np.ndarray to list
        list_val_max = max(val) #取得最大值
        list_val_maxIndex = val.index(max(val)) #取得最大值的索引  
        
        if list_val_max >=0 :
           #data_ho.append(str(m) + "分" + str(s) + "秒，出現:" + str(words[list_val_maxIndex]) + "，預測值:" + str(list_val_max))
            data.append(str(m) + "分" + str(s) + "秒，出現:" + str(words[list_val_maxIndex]) + "，預測值:" + str(list_val_max))
             
         
#main
# Parameters
num_mfcc = 23 #回傳mfcc的量
model_path = './tflite/appendEnergyTT_wen.tflite'
words = ['贅詞', '雜音']#答案對應到的字詞
data = []
data_ho = []
start = 0 #一開始的索引值
end = 2000 #一開始的索引值
s = 0 #秒
m = 0 #分
duration = 180 #讀音檔的總時間
sample_rate = 8000 #取樣率

#載入音檔
y, sr = librosa.load("./desktop/chen.wav",sr=sample_rate,duration=duration) 

# Sliding window
window = np.zeros(8000)#取樣音頻數據變數

# Load model (interpreter)
interpreter = tf.lite.Interpreter(model_path)
interpreter.allocate_tensors()
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()


while True:
    s = s + 0.25 #增加秒數
    if(s == 60): #60秒 轉成 1分
        s = 0
        m = m + 1

    #window[:4000] = window[4000:] #把音訊載入window
    #window[4000:] = y[start:end] #把音訊載入window
    window[0:2000] = window[2000:4000]
    window[2000:4000] = window[4000:6000]
    window[4000:6000] = window[6000:8000]
    window[6000:8000] = y[start:end]
    sound(window,s,m) #呼叫sound()

    if(end == (8000 * duration)): #如果移動到最後，break
        break
    
    start = start + 2000 #向後移動
    end = end + 2000 #向後移動    
    
    
for i in range(len(data)):
        print(data[i])
        
print(len(data))
# Out:
# 0分1.75秒，出現:贅詞，預測值:0.8790212869644165
# 0分2.0秒，出現:贅詞，預測值:0.9999096393585205
# 0分2.25秒，出現:贅詞，預測值:0.9999978542327881
# 0分2.5秒，出現:贅詞，預測值:0.9999996423721313
# 0分2.75秒，出現:贅詞，預測值:0.9999978542327881
# 0分3.0秒，出現:贅詞，預測值:0.997046172618866
# 0分3.25秒，出現:贅詞，預測值:0.9742343425750732
# 0分3.5秒，出現:贅詞，預測值:1.0
# 0分3.75秒，出現:贅詞，預測值:1.0
# 0分4.0秒，出現:贅詞，預測值:1.0
# 0分4.25秒，出現:贅詞，預測值:0.9999998807907104
# 0分4.5秒，出現:贅詞，預測值:0.9999991655349731
# 0分4.75秒，出現:贅詞，預測值:0.9999198913574219
# 0分5.0秒，出現:贅詞，預測值:0.9999909400939941
# 0分5.25秒，出現:贅詞，預測值:0.9999980926513672
# 0分5.5秒，出現:贅詞，預測值:1.0
# 0分5.75秒，出現:贅詞，預測值:0.9999990463256836
# 0分6.0秒，出現:贅詞，預測值:0.9999649524688721
# 0分6.25秒，出現:贅詞，預測值:0.9988560676574707
# 0分6.5秒，出現:贅詞，預測值:0.9999983310699463
# 0分6.75秒，出現:贅詞，預測值:0.9999998807907104
# 0分7.0秒，出現:贅詞，預測值:0.9999998807907104
# 0分7.25秒，出現:贅詞，預測值:0.9995267391204834
# 0分7.5秒，出現:贅詞，預測值:0.9954250454902649
# 0分7.75秒，出現:贅詞，預測值:0.9999998807907104
# 0分8.0秒，出現:贅詞，預測值:1.0
# 0分8.25秒，出現:贅詞，預測值:0.9999668598175049
# 0分8.5秒，出現:贅詞，預測值:0.9999856948852539
# 0分8.75秒，出現:贅詞，預測值:0.9999935626983643
# 0分9.0秒，出現:贅詞，預測值:0.9999996423721313
# 0分9.25秒，出現:贅詞，預測值:1.0
# 0分9.5秒，出現:贅詞，預測值:1.0
# 0分9.75秒，出現:贅詞，預測值:1.0
# 0分10.0秒，出現:贅詞，預測值:0.9999959468841553
# 0分10.25秒，出現:贅詞，預測值:0.9974799752235413
# 0分10.5秒，出現:贅詞，預測值:0.9997962117195129
# 0分10.75秒，出現:贅詞，預測值:0.9999996423721313
# 0分11.0秒，出現:贅詞，預測值:1.0
# 0分11.25秒，出現:贅詞，預測值:1.0
# 0分11.5秒，出現:贅詞，預測值:1.0
# 0分11.75秒，出現:贅詞，預測值:1.0
# 0分12.0秒，出現:贅詞，預測值:1.0
# 0分12.25秒，出現:贅詞，預測值:1.0
# 0分12.5秒，出現:贅詞，預測值:1.0
# 0分12.75秒，出現:贅詞，預測值:1.0
# 0分13.0秒，出現:贅詞，預測值:1.0
# 0分13.25秒，出現:贅詞，預測值:0.9999998807907104
# 0分13.5秒，出現:贅詞，預測值:1.0
# 0分13.75秒，出現:贅詞，預測值:0.9999998807907104
# 0分14.0秒，出現:贅詞，預測值:0.9999997615814209
# 0分14.25秒，出現:贅詞，預測值:0.9999996423721313
# 0分14.5秒，出現:贅詞，預測值:0.9999957084655762
# 0分14.75秒，出現:贅詞，預測值:0.999239444732666
# 0分15.0秒，出現:贅詞，預測值:0.9999998807907104
# 0分15.25秒，出現:贅詞，預測值:1.0
# 0分15.5秒，出現:贅詞，預測值:0.9999977350234985
# 0分15.75秒，出現:贅詞，預測值:0.9975497126579285
# 0分16.0秒，出現:贅詞，預測值:0.9999985694885254
# 0分16.25秒，出現:贅詞，預測值:0.9999960660934448
# 0分16.5秒，出現:贅詞，預測值:0.999963641166687
# 0分16.75秒，出現:贅詞，預測值:1.0
# 0分17.0秒，出現:贅詞，預測值:1.0
# 0分17.25秒，出現:贅詞，預測值:1.0
# 0分17.5秒，出現:贅詞，預測值:1.0
# 0分17.75秒，出現:贅詞，預測值:1.0
# 0分18.0秒，出現:贅詞，預測值:0.9999998807907104
# 0分18.25秒，出現:贅詞，預測值:1.0
# 0分18.5秒，出現:贅詞，預測值:1.0
# 0分18.75秒，出現:贅詞，預測值:0.9998656511306763
# 0分19.0秒，出現:贅詞，預測值:0.9998929500579834
# 0分19.25秒，出現:贅詞，預測值:0.9999109506607056
# 0分19.5秒，出現:贅詞，預測值:0.9999996423721313
# 0分19.75秒，出現:贅詞，預測值:0.9999924898147583
# 0分20.0秒，出現:贅詞，預測值:0.9977235198020935
# 0分20.25秒，出現:贅詞，預測值:0.9999092817306519
# 0分20.5秒，出現:贅詞，預測值:0.9444556832313538
# 0分20.75秒，出現:贅詞，預測值:0.9967696666717529
# 0分21.0秒，出現:贅詞，預測值:0.999881386756897
# 0分21.25秒，出現:贅詞，預測值:0.9999945163726807
# 0分21.5秒，出現:贅詞，預測值:0.9999936819076538
# 0分21.75秒，出現:贅詞，預測值:0.9997201561927795
# 0分22.0秒，出現:贅詞，預測值:1.0
# 0分22.25秒，出現:贅詞，預測值:1.0
# 0分22.5秒，出現:贅詞，預測值:0.9998093247413635
# 0分22.75秒，出現:贅詞，預測值:0.9942313432693481
# 0分23.0秒，出現:贅詞，預測值:0.9999996423721313
# 0分23.25秒，出現:贅詞，預測值:1.0
# 0分23.5秒，出現:贅詞，預測值:0.9999996423721313
# 0分23.75秒，出現:贅詞，預測值:1.0
# 0分24.0秒，出現:贅詞，預測值:1.0
# 0分24.25秒，出現:贅詞，預測值:1.0
# 0分24.5秒，出現:贅詞，預測值:1.0
# 0分24.75秒，出現:贅詞，預測值:0.9999998807907104
# 0分25.0秒，出現:贅詞，預測值:0.9999966621398926
# 0分25.25秒，出現:贅詞，預測值:0.9999992847442627
# 0分25.5秒，出現:贅詞，預測值:0.9999977350234985
# 0分25.75秒，出現:贅詞，預測值:0.999993085861206
# 0分26.0秒，出現:贅詞，預測值:0.9999804496765137
# 0分26.25秒，出現:贅詞，預測值:0.9999998807907104
# 0分26.5秒，出現:贅詞，預測值:0.9999977350234985
# 0分26.75秒，出現:贅詞，預測值:0.9999990463256836
# 0分27.0秒，出現:贅詞，預測值:1.0
# 0分27.25秒，出現:贅詞，預測值:1.0
# 0分27.5秒，出現:贅詞，預測值:0.9999991655349731
# 0分28.0秒，出現:贅詞，預測值:0.9999637603759766
# 0分28.25秒，出現:贅詞，預測值:0.9999988079071045
# 0分28.5秒，出現:贅詞，預測值:0.9999998807907104
# 0分28.75秒，出現:贅詞，預測值:1.0
# 0分29.0秒，出現:贅詞，預測值:1.0
# 0分29.25秒，出現:贅詞，預測值:1.0
# 0分29.5秒，出現:贅詞，預測值:1.0
# 0分29.75秒，出現:贅詞，預測值:1.0
# 0分30.0秒，出現:贅詞，預測值:1.0
# 0分30.25秒，出現:贅詞，預測值:1.0
# 0分30.5秒，出現:贅詞，預測值:1.0
# 0分30.75秒，出現:贅詞，預測值:1.0
# 0分31.0秒，出現:贅詞，預測值:1.0
# 0分31.25秒，出現:贅詞，預測值:1.0
# 0分31.5秒，出現:贅詞，預測值:1.0
# 0分31.75秒，出現:贅詞，預測值:1.0
# 0分32.0秒，出現:贅詞，預測值:1.0
# 0分32.25秒，出現:贅詞，預測值:1.0
# 0分32.5秒，出現:贅詞，預測值:1.0
# 0分32.75秒，出現:贅詞，預測值:1.0
# 0分33.0秒，出現:贅詞，預測值:1.0
# 0分33.25秒，出現:贅詞，預測值:1.0
# 0分33.5秒，出現:贅詞，預測值:0.9999997615814209
# 0分33.75秒，出現:贅詞，預測值:0.9999985694885254
# 0分34.0秒，出現:贅詞，預測值:1.0
# 0分34.25秒，出現:贅詞，預測值:1.0
# 0分34.5秒，出現:贅詞，預測值:0.9999991655349731
# 0分34.75秒，出現:贅詞，預測值:0.9988223910331726
# 0分35.0秒，出現:贅詞，預測值:0.9998365640640259
# 0分35.25秒，出現:贅詞，預測值:1.0
# 0分35.5秒，出現:贅詞，預測值:0.999992847442627
# 0分35.75秒，出現:贅詞，預測值:0.9999898672103882
# 0分36.25秒，出現:贅詞，預測值:0.9988391995429993
# 0分36.5秒，出現:贅詞，預測值:0.999969482421875
# 0分36.75秒，出現:贅詞，預測值:0.9999996423721313
# 0分37.0秒，出現:贅詞，預測值:1.0
# 0分37.25秒，出現:贅詞，預測值:1.0
# 0分37.5秒，出現:贅詞，預測值:1.0
# 0分37.75秒，出現:贅詞，預測值:1.0
# 0分38.0秒，出現:贅詞，預測值:1.0
# 0分38.25秒，出現:贅詞，預測值:1.0
# 0分38.5秒，出現:贅詞，預測值:1.0
# 0分38.75秒，出現:贅詞，預測值:1.0
# 0分39.0秒，出現:贅詞，預測值:0.9999961853027344
# 0分39.25秒，出現:贅詞，預測值:0.9999707937240601
# 0分39.5秒，出現:贅詞，預測值:0.999998927116394
# 0分39.75秒，出現:贅詞，預測值:0.9999990463256836
# 0分40.0秒，出現:贅詞，預測值:0.9997956156730652
# 0分40.25秒，出現:贅詞，預測值:0.9999977350234985
# 0分40.5秒，出現:贅詞，預測值:0.9999998807907104
# 0分40.75秒，出現:贅詞，預測值:0.999970555305481
# 0分41.0秒，出現:贅詞，預測值:0.9663262963294983
# 0分41.25秒，出現:雜音，預測值:0.5796130299568176
# 0分41.5秒，出現:雜音，預測值:0.9565466642379761
# 0分41.75秒，出現:贅詞，預測值:0.999980092048645
# 0分42.0秒，出現:贅詞，預測值:0.9999967813491821
# 0分42.25秒，出現:贅詞，預測值:0.999976396560669
# 0分42.5秒，出現:贅詞，預測值:1.0
# 0分42.75秒，出現:贅詞，預測值:1.0
# 0分43.0秒，出現:贅詞，預測值:0.9999980926513672
# 0分43.25秒，出現:贅詞，預測值:0.9998440742492676
# 0分43.5秒，出現:贅詞，預測值:0.9956360459327698
# 0分43.75秒，出現:贅詞，預測值:1.0
# 0分44.0秒，出現:贅詞，預測值:0.9999986886978149
# 0分44.25秒，出現:贅詞，預測值:0.9999994039535522
# 0分44.5秒，出現:贅詞，預測值:1.0
# 0分44.75秒，出現:贅詞，預測值:1.0
# 0分45.0秒，出現:贅詞，預測值:0.9999998807907104
# 0分45.25秒，出現:贅詞，預測值:1.0
# 0分45.5秒，出現:贅詞，預測值:0.9999998807907104
# 0分45.75秒，出現:贅詞，預測值:0.9999685287475586
# 0分46.0秒，出現:贅詞，預測值:1.0
# 0分46.25秒，出現:贅詞，預測值:1.0
# 0分46.5秒，出現:贅詞，預測值:1.0
# 0分48.25秒，出現:贅詞，預測值:0.9997919201850891
# 0分48.5秒，出現:贅詞，預測值:0.9999822378158569
# 0分48.75秒，出現:贅詞，預測值:0.9999992847442627
# 0分49.0秒，出現:贅詞，預測值:1.0
# 0分49.25秒，出現:贅詞，預測值:1.0
# 0分49.5秒，出現:贅詞，預測值:0.9905434250831604
# 0分51.0秒，出現:贅詞，預測值:0.9958113431930542
# 0分51.25秒，出現:贅詞，預測值:0.9999998807907104
# 0分51.5秒，出現:贅詞，預測值:1.0
# 0分51.75秒，出現:贅詞，預測值:1.0
# 0分52.0秒，出現:贅詞，預測值:1.0
# 0分52.25秒，出現:贅詞，預測值:0.9999997615814209
# 0分52.5秒，出現:贅詞，預測值:0.9999992847442627
# 0分52.75秒，出現:贅詞，預測值:0.9999998807907104
# 0分53.0秒，出現:贅詞，預測值:1.0
# 0分53.25秒，出現:贅詞，預測值:1.0
# 0分53.5秒，出現:贅詞，預測值:1.0
# 0分53.75秒，出現:贅詞，預測值:0.999996542930603
# 0分54.0秒，出現:贅詞，預測值:0.999988317489624
# 0分54.25秒，出現:贅詞，預測值:0.9999998807907104
# 0分54.5秒，出現:贅詞，預測值:0.9999998807907104
# 0分54.75秒，出現:贅詞，預測值:1.0
# 0分55.0秒，出現:贅詞，預測值:0.9999951124191284
# 0分55.25秒，出現:贅詞，預測值:0.999987006187439
# 0分55.5秒，出現:贅詞，預測值:0.9999909400939941
# 0分55.75秒，出現:贅詞，預測值:1.0
# 0分56.0秒，出現:贅詞，預測值:1.0
# 0分56.25秒，出現:贅詞，預測值:0.9999998807907104
# 0分56.5秒，出現:贅詞，預測值:0.9999995231628418
# 0分56.75秒，出現:贅詞，預測值:1.0
# 0分57.0秒，出現:贅詞，預測值:1.0
# 0分57.25秒，出現:贅詞，預測值:0.9999732971191406
# 0分57.5秒，出現:贅詞，預測值:0.947603166103363
# 0分57.75秒，出現:贅詞，預測值:0.7076060771942139
# 0分58.0秒，出現:贅詞，預測值:0.9951086640357971
# 0分58.25秒，出現:贅詞，預測值:0.9899643063545227
# 0分58.5秒，出現:贅詞，預測值:0.9996121525764465
# 0分58.75秒，出現:贅詞，預測值:0.9999996423721313
# 0分59.0秒，出現:贅詞，預測值:1.0
# 0分59.25秒，出現:贅詞，預測值:1.0
# 0分59.5秒，出現:贅詞，預測值:1.0
# 0分59.75秒，出現:贅詞，預測值:1.0
# 1分0秒，出現:贅詞，預測值:1.0
# 1分0.25秒，出現:贅詞，預測值:1.0
# 1分0.5秒，出現:贅詞，預測值:1.0
# 1分0.75秒，出現:贅詞，預測值:1.0
# 1分1.0秒，出現:贅詞，預測值:1.0
# 1分1.25秒，出現:贅詞，預測值:1.0
# 1分1.5秒，出現:贅詞，預測值:1.0
# 1分1.75秒，出現:贅詞，預測值:0.9999998807907104
# 1分2.0秒，出現:贅詞，預測值:1.0
# 1分2.25秒，出現:贅詞，預測值:1.0
# 1分2.5秒，出現:贅詞，預測值:0.9999990463256836
# 1分2.75秒，出現:贅詞，預測值:0.9999514818191528
# 1分3.0秒，出現:贅詞，預測值:0.9999992847442627
# 1分3.25秒，出現:贅詞，預測值:0.9999963045120239
# 1分3.5秒，出現:贅詞，預測值:0.9999963045120239
# 1分3.75秒，出現:贅詞，預測值:1.0
# 1分4.0秒，出現:贅詞，預測值:1.0
# 1分4.25秒，出現:贅詞，預測值:0.9999997615814209
# 1分7.25秒，出現:贅詞，預測值:0.9999350309371948
# 1分7.5秒，出現:贅詞，預測值:1.0
# 1分7.75秒，出現:贅詞，預測值:1.0
# 1分8.0秒，出現:贅詞，預測值:1.0
# 1分8.25秒，出現:贅詞，預測值:1.0
# 1分8.5秒，出現:贅詞，預測值:1.0
# 1分8.75秒，出現:贅詞，預測值:1.0
# 1分9.0秒，出現:贅詞，預測值:0.9999986886978149
# 1分10.5秒，出現:贅詞，預測值:0.9999990463256836
# 1分10.75秒，出現:贅詞，預測值:1.0
# 1分11.0秒，出現:贅詞，預測值:1.0
# 1分11.25秒，出現:贅詞，預測值:0.9999994039535522
# 1分11.5秒，出現:贅詞，預測值:0.9993112087249756
# 1分11.75秒，出現:贅詞，預測值:0.9999054670333862
# 1分12.0秒，出現:贅詞，預測值:1.0
# 1分12.25秒，出現:贅詞，預測值:1.0
# 1分12.5秒，出現:贅詞，預測值:0.9999991655349731
# 1分13.25秒，出現:贅詞，預測值:0.9939219951629639
# 1分13.5秒，出現:贅詞，預測值:0.9954180717468262
# 1分13.75秒，出現:贅詞，預測值:0.9999996423721313
# 1分14.0秒，出現:贅詞，預測值:1.0
# 1分14.25秒，出現:贅詞，預測值:1.0
# 1分14.5秒，出現:贅詞，預測值:1.0
# 1分14.75秒，出現:贅詞，預測值:1.0
# 1分15.0秒，出現:贅詞，預測值:1.0
# 1分15.25秒，出現:贅詞，預測值:1.0
# 1分15.5秒，出現:贅詞，預測值:1.0
# 1分15.75秒，出現:贅詞，預測值:1.0
# 1分16.0秒，出現:贅詞，預測值:0.9999994039535522
# 1分16.25秒，出現:贅詞，預測值:0.9999990463256836
# 1分16.5秒，出現:贅詞，預測值:0.9999909400939941
# 1分16.75秒，出現:贅詞，預測值:0.9997459053993225
# 1分17.0秒，出現:贅詞，預測值:1.0
# 1分17.25秒，出現:贅詞，預測值:1.0
# 1分17.5秒，出現:贅詞，預測值:0.9999991655349731
# 1分17.75秒，出現:贅詞，預測值:1.0
# 1分18.0秒，出現:贅詞，預測值:1.0
# 1分18.25秒，出現:贅詞，預測值:0.9999992847442627
# 1分18.5秒，出現:贅詞，預測值:0.9999865293502808
# 1分18.75秒，出現:贅詞，預測值:0.9999980926513672
# 1分19.0秒，出現:贅詞，預測值:1.0
# 1分19.25秒，出現:贅詞，預測值:0.9999998807907104
# 1分19.5秒，出現:贅詞，預測值:1.0
# 1分19.75秒，出現:贅詞，預測值:0.9999998807907104
# 1分20.0秒，出現:贅詞，預測值:0.9999486207962036
# 1分20.25秒，出現:贅詞，預測值:0.9999741315841675
# 1分20.5秒，出現:贅詞，預測值:0.999957799911499
# 1分20.75秒，出現:贅詞，預測值:0.9999896287918091
# 1分21.0秒，出現:贅詞，預測值:0.9999977350234985
# 1分21.25秒，出現:贅詞，預測值:1.0
# 1分21.5秒，出現:贅詞，預測值:1.0
# 1分21.75秒，出現:贅詞，預測值:1.0
# 1分22.0秒，出現:贅詞，預測值:1.0
# 1分22.25秒，出現:贅詞，預測值:1.0
# 1分22.5秒，出現:贅詞，預測值:0.9999997615814209
# 1分22.75秒，出現:贅詞，預測值:1.0
# 1分23.0秒，出現:贅詞，預測值:0.999778687953949
# 1分23.5秒，出現:贅詞，預測值:0.9996970891952515
# 1分23.75秒，出現:贅詞，預測值:0.9999996423721313
# 1分24.0秒，出現:贅詞，預測值:0.9999998807907104
# 1分24.25秒，出現:贅詞，預測值:1.0
# 1分24.5秒，出現:贅詞，預測值:1.0
# 1分24.75秒，出現:贅詞，預測值:0.9999997615814209
# 1分25.0秒，出現:贅詞，預測值:0.9999353885650635
# 1分25.25秒，出現:贅詞，預測值:0.9345082640647888
# 1分25.5秒，出現:贅詞，預測值:0.9999998807907104
# 1分25.75秒，出現:贅詞，預測值:1.0
# 1分26.0秒，出現:贅詞，預測值:0.9999980926513672
# 1分26.25秒，出現:贅詞，預測值:1.0
# 1分26.5秒，出現:贅詞，預測值:1.0
# 1分26.75秒，出現:贅詞，預測值:1.0
# 1分27.0秒，出現:贅詞，預測值:1.0
# 1分27.25秒，出現:贅詞，預測值:1.0
# 1分27.5秒，出現:贅詞，預測值:0.9999998807907104
# 1分27.75秒，出現:贅詞，預測值:1.0
# 1分28.0秒，出現:贅詞，預測值:1.0
# 1分28.25秒，出現:贅詞，預測值:0.9999998807907104
# 1分28.5秒，出現:贅詞，預測值:1.0
# 1分28.75秒，出現:贅詞，預測值:0.9999998807907104
# 1分29.0秒，出現:贅詞，預測值:0.9999982118606567
# 1分29.25秒，出現:贅詞，預測值:1.0
# 1分29.5秒，出現:贅詞，預測值:1.0
# 1分29.75秒，出現:贅詞，預測值:1.0
# 1分30.0秒，出現:贅詞，預測值:1.0
# 1分30.25秒，出現:贅詞，預測值:0.9999988079071045
# 1分30.5秒，出現:贅詞，預測值:1.0
# 1分30.75秒，出現:贅詞，預測值:0.9999933242797852
# 1分31.0秒，出現:贅詞，預測值:0.9999467134475708
# 1分31.25秒，出現:贅詞，預測值:0.9999998807907104
# 1分31.5秒，出現:贅詞，預測值:1.0
# 1分31.75秒，出現:贅詞，預測值:1.0
# 1分32.0秒，出現:贅詞，預測值:1.0
# 1分32.25秒，出現:贅詞，預測值:1.0
# 1分32.5秒，出現:贅詞，預測值:1.0
# 1分32.75秒，出現:贅詞，預測值:0.9999991655349731
# 1分33.0秒，出現:贅詞，預測值:1.0
# 1分33.25秒，出現:贅詞，預測值:1.0
# 1分33.5秒，出現:贅詞，預測值:1.0
# 1分33.75秒，出現:贅詞，預測值:1.0
# 1分34.0秒，出現:贅詞，預測值:1.0
# 1分34.25秒，出現:贅詞，預測值:1.0
# 1分34.5秒，出現:贅詞，預測值:0.999992847442627
# 1分34.75秒，出現:贅詞，預測值:0.9996442794799805
# 1分35.0秒，出現:贅詞，預測值:0.9996421337127686
# 1分35.25秒，出現:贅詞，預測值:0.9992658495903015
# 1分35.5秒，出現:贅詞，預測值:0.999976634979248
# 1分35.75秒，出現:贅詞，預測值:1.0
# 1分36.0秒，出現:贅詞，預測值:1.0
# 1分36.25秒，出現:贅詞，預測值:1.0
# 1分36.5秒，出現:贅詞，預測值:0.9999996423721313
# 1分36.75秒，出現:贅詞，預測值:0.9999998807907104
# 1分37.0秒，出現:贅詞，預測值:1.0
# 1分37.25秒，出現:贅詞，預測值:1.0
# 1分37.5秒，出現:贅詞，預測值:1.0
# 1分37.75秒，出現:贅詞，預測值:1.0
# 1分38.0秒，出現:贅詞，預測值:0.9999996423721313
# 1分38.25秒，出現:贅詞，預測值:0.9999995231628418
# 1分38.5秒，出現:贅詞，預測值:0.9457458853721619
# 1分38.75秒，出現:贅詞，預測值:0.9990679621696472
# 1分39.0秒，出現:贅詞，預測值:0.9999780654907227
# 1分39.25秒，出現:贅詞，預測值:0.9999991655349731
# 1分39.5秒，出現:贅詞，預測值:1.0
# 1分39.75秒，出現:贅詞，預測值:0.9999998807907104
# 1分40.0秒，出現:贅詞，預測值:0.9999994039535522
# 1分40.25秒，出現:贅詞，預測值:1.0
# 1分40.5秒，出現:贅詞，預測值:0.9999992847442627
# 1分40.75秒，出現:贅詞，預測值:0.9999969005584717
# 1分41.0秒，出現:贅詞，預測值:1.0
# 1分41.25秒，出現:贅詞，預測值:1.0
# 1分41.5秒，出現:贅詞，預測值:1.0
# 1分41.75秒，出現:贅詞，預測值:1.0
# 1分42.0秒，出現:贅詞，預測值:1.0
# 1分42.25秒，出現:贅詞，預測值:0.9999996423721313
# 1分42.5秒，出現:贅詞，預測值:0.9999997615814209
# 1分42.75秒，出現:贅詞，預測值:0.9999996423721313
# 1分43.0秒，出現:贅詞，預測值:0.9999998807907104
# 1分43.25秒，出現:贅詞，預測值:0.9999998807907104
# 1分43.5秒，出現:贅詞，預測值:0.9999709129333496
# 1分43.75秒，出現:贅詞，預測值:0.9999986886978149
# 1分44.0秒，出現:贅詞，預測值:1.0
# 1分44.25秒，出現:贅詞，預測值:1.0
# 1分44.5秒，出現:贅詞，預測值:0.9999935626983643
# 1分44.75秒，出現:贅詞，預測值:0.9999853372573853
# 1分45.0秒，出現:雜音，預測值:0.5671066641807556
# 1分45.25秒，出現:贅詞，預測值:0.9989443421363831
# 1分45.5秒，出現:贅詞，預測值:1.0
# 1分45.75秒，出現:贅詞，預測值:1.0
# 1分46.0秒，出現:贅詞，預測值:1.0
# 1分46.25秒，出現:贅詞，預測值:0.9999998807907104
# 1分46.5秒，出現:贅詞，預測值:1.0
# 1分46.75秒，出現:贅詞，預測值:1.0
# 1分47.0秒，出現:贅詞，預測值:1.0
# 1分47.25秒，出現:贅詞，預測值:0.9997863173484802
# 1分47.5秒，出現:贅詞，預測值:0.9998220801353455
# 1分47.75秒，出現:贅詞，預測值:0.9999902248382568
# 1分48.0秒，出現:贅詞，預測值:0.999998927116394
# 1分48.25秒，出現:贅詞，預測值:0.9999998807907104
# 1分48.5秒，出現:贅詞，預測值:1.0
# 1分48.75秒，出現:贅詞，預測值:1.0
# 1分49.0秒，出現:贅詞，預測值:1.0
# 1分49.25秒，出現:贅詞，預測值:1.0
# 1分49.5秒，出現:贅詞，預測值:0.9999778270721436
# 1分49.75秒，出現:贅詞，預測值:1.0
# 1分50.0秒，出現:贅詞，預測值:1.0
# 1分50.25秒，出現:贅詞，預測值:0.9999995231628418
# 1分50.5秒，出現:贅詞，預測值:0.9999977350234985
# 1分50.75秒，出現:贅詞，預測值:1.0
# 1分51.0秒，出現:贅詞，預測值:0.9999995231628418
# 1分51.25秒，出現:贅詞，預測值:1.0
# 1分51.5秒，出現:贅詞，預測值:1.0
# 1分51.75秒，出現:贅詞，預測值:1.0
# 1分52.0秒，出現:贅詞，預測值:1.0
# 1分52.25秒，出現:贅詞，預測值:1.0
# 1分52.5秒，出現:贅詞，預測值:1.0
# 1分52.75秒，出現:贅詞，預測值:1.0
# 1分53.0秒，出現:贅詞，預測值:1.0
# 1分53.25秒，出現:贅詞，預測值:0.9999978542327881
# 1分53.5秒，出現:贅詞，預測值:0.9999995231628418
# 1分53.75秒，出現:贅詞，預測值:1.0
# 1分54.0秒，出現:贅詞，預測值:0.9999980926513672
# 1分54.25秒，出現:贅詞，預測值:0.9997616410255432
# 1分54.5秒，出現:贅詞，預測值:0.9999938011169434
# 1分54.75秒，出現:贅詞，預測值:0.999998927116394
# 1分55.0秒，出現:贅詞，預測值:1.0
# 1分55.25秒，出現:贅詞，預測值:0.9999932050704956
# 1分55.5秒，出現:贅詞，預測值:0.9999947547912598
# 1分55.75秒，出現:贅詞，預測值:0.9999997615814209
# 1分56.0秒，出現:贅詞，預測值:0.9999980926513672
# 1分56.25秒，出現:贅詞，預測值:0.99998939037323
# 1分56.5秒，出現:贅詞，預測值:1.0
# 1分56.75秒，出現:贅詞，預測值:1.0
# 1分57.0秒，出現:贅詞，預測值:0.9999939203262329
# 1分57.25秒，出現:贅詞，預測值:1.0
# 1分57.5秒，出現:贅詞，預測值:1.0
# 1分57.75秒，出現:贅詞，預測值:1.0
# 1分58.0秒，出現:贅詞，預測值:1.0
# 1分58.25秒，出現:贅詞，預測值:0.9944555163383484
# 1分58.5秒，出現:贅詞，預測值:0.9999991655349731
# 1分58.75秒，出現:贅詞，預測值:0.9999951124191284
# 1分59.0秒，出現:贅詞，預測值:0.9985308647155762
# 1分59.25秒，出現:贅詞，預測值:0.9999998807907104
# 1分59.5秒，出現:贅詞，預測值:0.9999992847442627
# 1分59.75秒，出現:贅詞，預測值:0.9977839589118958
# 2分0秒，出現:贅詞，預測值:0.9999992847442627
# 2分0.25秒，出現:贅詞，預測值:1.0
# 2分0.5秒，出現:贅詞，預測值:1.0
# 2分0.75秒，出現:贅詞，預測值:0.9994469285011292
# 2分1.0秒，出現:贅詞，預測值:0.9995130300521851
# 2分1.25秒，出現:贅詞，預測值:0.9999909400939941
# 2分1.5秒，出現:贅詞，預測值:1.0
# 2分1.75秒，出現:贅詞，預測值:1.0
# 2分2.0秒，出現:贅詞，預測值:0.9999996423721313
# 2分2.25秒，出現:贅詞，預測值:0.9999756813049316
# 2分2.5秒，出現:贅詞，預測值:0.9999724626541138
# 2分2.75秒，出現:贅詞，預測值:1.0
# 2分3.0秒，出現:贅詞，預測值:0.9999963045120239
# 2分3.25秒，出現:贅詞，預測值:0.9893890023231506
# 2分3.5秒，出現:贅詞，預測值:0.9052891135215759
# 2分3.75秒，出現:贅詞，預測值:0.9998767375946045
# 2分4.0秒，出現:贅詞，預測值:0.9999995231628418
# 2分4.25秒，出現:贅詞，預測值:0.9999997615814209
# 2分4.5秒，出現:贅詞，預測值:0.9999996423721313
# 2分4.75秒，出現:贅詞，預測值:1.0
# 2分5.0秒，出現:贅詞，預測值:0.9999898672103882
# 2分5.25秒，出現:贅詞，預測值:1.0
# 2分5.5秒，出現:贅詞，預測值:1.0
# 2分5.75秒，出現:贅詞，預測值:0.9999998807907104
# 2分6.0秒，出現:贅詞，預測值:0.9999998807907104
# 2分6.25秒，出現:贅詞，預測值:1.0
# 2分6.5秒，出現:贅詞，預測值:1.0
# 2分6.75秒，出現:贅詞，預測值:1.0
# 2分7.0秒，出現:贅詞，預測值:0.9999998807907104
# 2分7.25秒，出現:贅詞，預測值:0.9999997615814209
# 2分7.5秒，出現:贅詞，預測值:0.9999912977218628
# 2分7.75秒，出現:贅詞，預測值:0.9999998807907104
# 2分8.0秒，出現:贅詞，預測值:1.0
# 2分8.25秒，出現:贅詞，預測值:0.9999997615814209
# 2分8.5秒，出現:贅詞，預測值:0.9995298385620117
# 2分8.75秒，出現:贅詞，預測值:0.9999552965164185
# 2分9.0秒，出現:贅詞，預測值:0.9999741315841675
# 2分9.25秒，出現:贅詞，預測值:0.9997028708457947
# 2分9.5秒，出現:贅詞，預測值:0.9759957194328308
# 2分9.75秒，出現:贅詞，預測值:0.9999516010284424
# 2分10.0秒，出現:贅詞，預測值:0.9999998807907104
# 2分10.25秒，出現:贅詞，預測值:1.0
# 2分10.5秒，出現:贅詞，預測值:1.0
# 2分10.75秒，出現:贅詞，預測值:1.0
# 2分11.0秒，出現:贅詞，預測值:1.0
# 2分11.25秒，出現:贅詞，預測值:0.9998027682304382
# 2分11.5秒，出現:贅詞，預測值:0.9999938011169434
# 2分11.75秒，出現:贅詞，預測值:0.9999998807907104
# 2分12.0秒，出現:贅詞，預測值:1.0
# 2分12.25秒，出現:贅詞，預測值:1.0
# 2分12.5秒，出現:贅詞，預測值:0.9999946355819702
# 2分12.75秒，出現:贅詞，預測值:0.9999995231628418
# 2分13.0秒，出現:贅詞，預測值:0.9999990463256836
# 2分13.25秒，出現:贅詞，預測值:0.9995086193084717
# 2分13.5秒，出現:贅詞，預測值:0.9999783039093018
# 2分13.75秒，出現:贅詞，預測值:0.997257649898529
# 2分14.0秒，出現:贅詞，預測值:0.9999973773956299
# 2分14.25秒，出現:贅詞，預測值:0.9999994039535522
# 2分14.5秒，出現:贅詞，預測值:0.9999994039535522
# 2分14.75秒，出現:贅詞，預測值:1.0
# 2分15.0秒，出現:贅詞，預測值:1.0
# 2分15.25秒，出現:贅詞，預測值:1.0
# 2分15.5秒，出現:贅詞，預測值:0.9989436268806458
# 2分15.75秒，出現:贅詞，預測值:0.9837570786476135
# 2分16.0秒，出現:贅詞，預測值:0.9999972581863403
# 2分16.25秒，出現:贅詞，預測值:0.9999997615814209
# 2分16.5秒，出現:贅詞，預測值:0.9999948740005493
# 2分16.75秒，出現:贅詞，預測值:0.959858238697052
# 2分17.0秒，出現:贅詞，預測值:0.9999980926513672
# 2分17.25秒，出現:贅詞，預測值:0.9999850988388062
# 2分17.5秒，出現:贅詞，預測值:0.9999986886978149
# 2分17.75秒，出現:贅詞，預測值:0.9999325275421143
# 2分18.0秒，出現:贅詞，預測值:0.9999998807907104
# 2分18.25秒，出現:贅詞，預測值:1.0
# 2分18.5秒，出現:贅詞，預測值:1.0
# 2分18.75秒，出現:贅詞，預測值:1.0
# 2分19.0秒，出現:贅詞，預測值:0.9999994039535522
# 2分19.25秒，出現:贅詞，預測值:0.9997332692146301
# 2分19.5秒，出現:贅詞，預測值:0.9998384714126587
# 2分19.75秒，出現:贅詞，預測值:0.9999634027481079
# 2分20.0秒，出現:贅詞，預測值:1.0
# 2分20.25秒，出現:贅詞，預測值:0.9999998807907104
# 2分20.5秒，出現:贅詞，預測值:1.0
# 2分20.75秒，出現:贅詞，預測值:1.0
# 2分21.0秒，出現:贅詞，預測值:1.0
# 2分21.25秒，出現:贅詞，預測值:1.0
# 2分21.5秒，出現:贅詞，預測值:0.9999840259552002
# 2分21.75秒，出現:贅詞，預測值:1.0
# 2分22.0秒，出現:贅詞，預測值:1.0
# 2分22.25秒，出現:贅詞，預測值:0.9999995231628418
# 2分22.5秒，出現:贅詞，預測值:1.0
# 2分22.75秒，出現:贅詞，預測值:0.9998093247413635
# 2分23.0秒，出現:贅詞，預測值:0.9999699592590332
# 2分23.25秒，出現:贅詞，預測值:1.0
# 2分23.5秒，出現:贅詞，預測值:1.0
# 2分23.75秒，出現:贅詞，預測值:0.9962944388389587
# 2分24.0秒，出現:贅詞，預測值:0.9999998807907104
# 2分24.25秒，出現:贅詞，預測值:1.0
# 2分24.5秒，出現:贅詞，預測值:1.0
# 2分24.75秒，出現:贅詞，預測值:1.0
# 2分25.0秒，出現:贅詞，預測值:1.0
# 2分25.25秒，出現:贅詞，預測值:0.9999997615814209
# 2分25.5秒，出現:贅詞，預測值:1.0
# 2分25.75秒，出現:贅詞，預測值:1.0
# 2分26.0秒，出現:贅詞，預測值:0.9999998807907104
# 2分26.25秒，出現:贅詞，預測值:0.9999939203262329
# 2分26.5秒，出現:贅詞，預測值:0.9999985694885254
# 2分26.75秒，出現:贅詞，預測值:0.9999994039535522
# 2分27.0秒，出現:贅詞，預測值:0.9999911785125732
# 2分27.25秒，出現:贅詞，預測值:0.9999866485595703
# 2分27.5秒，出現:贅詞，預測值:0.9999960660934448
# 2分27.75秒，出現:贅詞，預測值:1.0
# 2分28.0秒，出現:贅詞，預測值:0.999991774559021
# 2分28.25秒，出現:贅詞，預測值:0.9999990463256836
# 2分28.5秒，出現:贅詞，預測值:0.9999998807907104
# 2分28.75秒，出現:贅詞，預測值:1.0
# 2分29.0秒，出現:贅詞，預測值:0.9999953508377075
# 2分29.25秒，出現:贅詞，預測值:0.9999986886978149
# 2分29.5秒，出現:贅詞，預測值:0.9999998807907104
# 2分29.75秒，出現:贅詞，預測值:0.9999796152114868
# 2分30.0秒，出現:贅詞，預測值:0.9999858140945435
# 2分30.25秒，出現:贅詞，預測值:0.9999982118606567
# 2分30.5秒，出現:贅詞，預測值:1.0
# 2分30.75秒，出現:贅詞，預測值:1.0
# 2分31.0秒，出現:贅詞，預測值:1.0
# 2分31.25秒，出現:贅詞，預測值:0.9999363422393799
# 2分31.5秒，出現:贅詞，預測值:0.9999991655349731
# 2分31.75秒，出現:贅詞，預測值:0.9999996423721313
# 2分32.0秒，出現:贅詞，預測值:0.9999605417251587
# 2分32.25秒，出現:贅詞，預測值:0.999984622001648
# 2分32.5秒，出現:贅詞，預測值:0.7769867181777954
# 2分32.75秒，出現:贅詞，預測值:0.8064805865287781
# 2分33.0秒，出現:贅詞，預測值:0.999976396560669
# 2分33.25秒，出現:贅詞，預測值:0.9315907955169678
# 2分33.5秒，出現:贅詞，預測值:0.9999998807907104
# 2分33.75秒，出現:贅詞，預測值:1.0
# 2分34.0秒，出現:贅詞，預測值:0.9999996423721313
# 2分34.25秒，出現:贅詞，預測值:0.9957745671272278
# 2分34.5秒，出現:贅詞，預測值:0.9999945163726807
# 2分34.75秒，出現:贅詞，預測值:1.0
# 2分35.0秒，出現:贅詞，預測值:1.0
# 2分35.25秒，出現:贅詞，預測值:0.9999996423721313
# 2分35.5秒，出現:贅詞，預測值:0.9999964237213135
# 2分35.75秒，出現:贅詞，預測值:1.0
# 2分36.0秒，出現:贅詞，預測值:1.0
# 2分36.25秒，出現:贅詞，預測值:1.0
# 2分36.5秒，出現:贅詞，預測值:0.9999983310699463
# 2分36.75秒，出現:贅詞，預測值:0.9999960660934448
# 2分37.0秒，出現:贅詞，預測值:1.0
# 2分37.25秒，出現:贅詞，預測值:1.0
# 2分37.5秒，出現:贅詞，預測值:0.9999450445175171
# 2分37.75秒，出現:贅詞，預測值:0.9999890327453613
# 2分38.0秒，出現:贅詞，預測值:0.9999645948410034
# 2分38.25秒，出現:贅詞，預測值:0.999990701675415
# 2分38.5秒，出現:贅詞，預測值:0.9999911785125732
# 2分38.75秒，出現:贅詞，預測值:0.9999957084655762
# 2分39.0秒，出現:贅詞，預測值:1.0
# 2分39.25秒，出現:贅詞，預測值:0.9999998807907104
# 2分39.5秒，出現:贅詞，預測值:1.0
# 2分39.75秒，出現:贅詞，預測值:1.0
# 2分40.0秒，出現:贅詞，預測值:0.9999969005584717
# 2分40.25秒，出現:贅詞，預測值:0.9980477094650269
# 2分40.5秒，出現:贅詞，預測值:0.9999949932098389
# 2分40.75秒，出現:贅詞，預測值:0.9999991655349731
# 2分41.0秒，出現:贅詞，預測值:1.0
# 2分41.25秒，出現:贅詞，預測值:0.9999997615814209
# 2分41.5秒，出現:贅詞，預測值:0.9995660185813904
# 2分41.75秒，出現:贅詞，預測值:0.9999996423721313
# 2分42.0秒，出現:贅詞，預測值:0.9999995231628418
# 2分42.25秒，出現:贅詞，預測值:1.0
# 2分42.5秒，出現:贅詞，預測值:1.0
# 2分42.75秒，出現:贅詞，預測值:0.9999997615814209
# 2分43.0秒，出現:贅詞，預測值:0.9999995231628418
# 2分43.25秒，出現:贅詞，預測值:0.9984369874000549
# 2分43.5秒，出現:贅詞，預測值:0.9997325539588928
# 2分43.75秒，出現:贅詞，預測值:0.9999998807907104
# 2分44.0秒，出現:贅詞，預測值:1.0
# 2分44.25秒，出現:贅詞，預測值:0.9999933242797852
# 2分44.5秒，出現:贅詞，預測值:0.9945687055587769
# 2分44.75秒，出現:贅詞，預測值:0.9999986886978149
# 2分45.0秒，出現:贅詞，預測值:0.9999969005584717
# 2分45.25秒，出現:贅詞，預測值:0.9999338388442993
# 2分45.5秒，出現:贅詞，預測值:1.0
# 2分45.75秒，出現:贅詞，預測值:1.0
# 2分46.0秒，出現:贅詞，預測值:1.0
# 2分46.25秒，出現:贅詞，預測值:1.0
# 2分46.5秒，出現:贅詞，預測值:1.0
# 2分46.75秒，出現:贅詞，預測值:0.9999762773513794
# 2分47.0秒，出現:贅詞，預測值:0.9999791383743286
# 2分47.25秒，出現:贅詞，預測值:1.0
# 2分47.5秒，出現:贅詞，預測值:1.0
# 2分47.75秒，出現:贅詞，預測值:0.9999366998672485
# 2分48.0秒，出現:贅詞，預測值:0.9999991655349731
# 2分48.25秒，出現:贅詞，預測值:1.0
# 2分48.5秒，出現:贅詞，預測值:1.0
# 2分48.75秒，出現:贅詞，預測值:1.0
# 2分49.0秒，出現:贅詞，預測值:0.9999873638153076
# 2分49.25秒，出現:贅詞，預測值:1.0
# 2分49.5秒，出現:贅詞，預測值:1.0
# 2分49.75秒，出現:贅詞，預測值:1.0
# 2分50.0秒，出現:贅詞，預測值:0.9999998807907104
# 2分50.25秒，出現:贅詞，預測值:0.9999991655349731
# 2分50.5秒，出現:贅詞，預測值:0.9999995231628418
# 2分50.75秒，出現:贅詞，預測值:0.99883633852005
# 2分51.0秒，出現:贅詞，預測值:0.7918504476547241
# 2分51.25秒，出現:贅詞，預測值:0.9718161225318909
# 2分51.5秒，出現:贅詞，預測值:0.9999985694885254
# 2分51.75秒，出現:贅詞，預測值:1.0
# 2分52.0秒，出現:贅詞，預測值:1.0
# 2分52.25秒，出現:贅詞，預測值:0.9999995231628418
# 2分52.5秒，出現:贅詞，預測值:0.999997615814209
# 2分52.75秒，出現:贅詞，預測值:0.9998258948326111
# 2分53.0秒，出現:贅詞，預測值:0.9999241828918457
# 2分53.25秒，出現:贅詞，預測值:0.9999986886978149
# 2分53.5秒，出現:贅詞，預測值:1.0
# 2分53.75秒，出現:贅詞，預測值:1.0
# 2分54.0秒，出現:贅詞，預測值:0.9999996423721313
# 2分54.25秒，出現:贅詞，預測值:0.9999933242797852
# 2分54.5秒，出現:贅詞，預測值:0.9996265172958374
# 2分54.75秒，出現:贅詞，預測值:0.9986749291419983
# 2分55.0秒，出現:贅詞，預測值:0.9998828172683716
# 2分55.25秒，出現:贅詞，預測值:0.9780591726303101
# 663
